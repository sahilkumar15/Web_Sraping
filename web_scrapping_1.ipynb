# %% [markdown]
# ### If You want to scrape a website:
# 1. use the Api
# 2. HTML Web Scrapping using some tools

# %% [markdown]
# # Import Libraries

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://scikit-learn.org/stable/"

# %% [markdown]
# # Step 1: Get the HTML

# %%
r = requests.get(url)
htmlContent = r.content

# %%
htmlContent
# Out:
# b'\n\n<!DOCTYPE html>\n<!--[if IE 8]><html class="no-js lt-ie9" lang="en" > <![endif]-->\n<!--[if gt IE 8]><!--> <html class="no-js" lang="en" > <!--<![endif]-->\n<head>\n  <meta charset="utf-8">\n  \n  <meta name="viewport" content="width=device-width, initial-scale=1.0">\n  <meta name="Description" content="scikit-learn: machine learning in Python">\n\n  \n  <title>scikit-learn: machine learning in Python &mdash; scikit-learn 0.22 documentation</title>\n  \n  <link rel="canonical" href="http://scikit-learn.org/stable/index.html" />\n\n  \n  <link rel="shortcut icon" href="_static/favicon.ico"/>\n  \n\n  <link rel="stylesheet" href="_static/css/vendor/bootstrap.min.css" type="text/css" />\n  <link rel="stylesheet" href="_static/gallery.css" type="text/css" />\n  <link rel="stylesheet" href="_static/css/theme.css" type="text/css" />\n<script id="documentation_options" data-url_root="./" src="_static/documentation_options.js"></script>\n<script src="_static/jquery.js"></script> \n</head>\n<body>\n<nav id="navbar" class="sk-landing-navbar navbar navbar-expand-md navbar-light bg-light py-0">\n  <div class="container-fluid sk-landing-container px-0">\n      <a class="navbar-brand py-0" href="#">\n        <img\n          class="sk-brand-img"\n          src="_static/scikit-learn-logo-small.png"\n          alt="logo"/>\n      </a>\n    <button\n      id="sk-navbar-toggler"\n      class="navbar-toggler"\n      type="button"\n      data-toggle="collapse"\n      data-target="#navbarSupportedContent"\n      aria-controls="navbarSupportedContent"\n      aria-expanded="false"\n      aria-label="Toggle navigation"\n    >\n      <span class="navbar-toggler-icon"></span>\n    </button>\n\n    <div class="sk-navbar-collapse collapse navbar-collapse" id="navbarSupportedContent">\n      <ul class="navbar-nav mr-auto">\n        <li class="nav-item">\n          <a class="sk-nav-link nav-link" href="install.html">Install</a>\n        </li>\n        <li class="nav-item">\n          <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>\n        </li>\n        <li class="nav-item">\n          <a class="sk-nav-link nav-link" href="modules/classes.html">API</a>\n        </li>\n        <li class="nav-item">\n          <a class="sk-nav-link nav-link" href="auto_examples/index.html">Examples</a>\n        </li>\n        <li class="nav-item">\n          <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="getting_started.html">Getting Started</a>\n        </li>\n        <li class="nav-item">\n          <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="tutorial/index.html">Tutorial</a>\n        </li>\n        <li class="nav-item">\n          <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="glossary.html">Glossary</a>\n        </li>\n        <li class="nav-item">\n          <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="developers/index.html">Development</a>\n        </li>\n        <li class="nav-item">\n          <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="faq.html">FAQ</a>\n        </li>\n        <li class="nav-item">\n          <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="related_projects.html">Related packages</a>\n        </li>\n        <li class="nav-item">\n          <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="roadmap.html">Roadmap</a>\n        </li>\n        <li class="nav-item">\n          <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="about.html">About us</a>\n        </li>\n        <li class="nav-item">\n          <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>\n        </li>\n        <li class="nav-item">\n          <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>\n        </li>\n        <li class="nav-item dropdown nav-more-item-dropdown">\n   ...

# %% [markdown]
# # Step 2: Parse the HTML

# %%
soup = BeautifulSoup(htmlContent, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if IE 8]><html class="no-js lt-ie9" lang="en" > <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="scikit-learn: machine learning in Python" name="Description"/>
# <title>scikit-learn: machine learning in Python — scikit-learn 0.22 documentation</title>
# <link href="http://scikit-learn.org/stable/index.html" rel="canonical"/>
# <link href="_static/favicon.ico" rel="shortcut icon"/>
# <link href="_static/css/vendor/bootstrap.min.css" rel="stylesheet" type="text/css"/>
# <link href="_static/gallery.css" rel="stylesheet" type="text/css"/>
# <link href="_static/css/theme.css" rel="stylesheet" type="text/css"/>
# <script data-url_root="./" id="documentation_options" src="_static/documentation_options.js"></script>
# <script src="_static/jquery.js"></script>
# </head>
# <body>
# <nav class="sk-landing-navbar navbar navbar-expand-md navbar-light bg-light py-0" id="navbar">
# <div class="container-fluid sk-landing-container px-0">
# <a class="navbar-brand py-0" href="#">
# <img alt="logo" class="sk-brand-img" src="_static/scikit-learn-logo-small.png"/>
# </a>
# <button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#navbarSupportedContent" data-toggle="collapse" id="sk-navbar-toggler" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <div class="sk-navbar-collapse collapse navbar-collapse" id="navbarSupportedContent">
# <ul class="navbar-nav mr-auto">
# <li class="nav-item">
# <a class="sk-nav-link nav-link" href="install.html">Install</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link" href="modules/classes.html">API</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link" href="auto_examples/index.html">Examples</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="getting_started.html">Getting Started</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="tutorial/index.html">Tutorial</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="glossary.html">Glossary</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="developers/index.html">Development</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="faq.html">FAQ</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="related_projects.html">Related packages</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="roadmap.html">Roadmap</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="about.html">About us</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>
# </li>
# <li class="nav-item dropdown nav-more-item-dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="sk-nav-link nav-link dropdown-toggle" data-toggle="dropdown" href="#" id="navbarDropdown" role="button">More</a>
# <div aria-labelledby="navbarDropdown" class="dropdown-menu">
# <a class="sk-nav-dropdown-item dropdown-item" href="getting_started.html">Getting Started</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="tutorial/index.html">Tutorial</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="glossary.html">Glossary</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="developers/index.html">Development</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="faq.html">FAQ</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="related_projects.html">Related packages</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="roadmap.html">Roadmap</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="about.html">About us</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>
# </div>
# </li>
# </ul>
# <div id="searchbox" role="search">
# <div class="searchformwrapper">
# <form action="search.html" class="search" method="get">
# <input aria-labelledby="searchlabel" class="sk-search-text-input" name="q" type="text"/>
# <input class="sk-search-text-btn" type="submit" value="Go"/>
# </form>
# </div>
# </div>
# </div>
# </div>
# </nav>
# <div class="container-fluid sk-landing-bg py-3">
# <div class="container sk-landing-container">
# <div class="row">
# <div class="col-md-6 mb-3 mb-md-0">
# <h1 class="sk-landing-header text-white text-monospace">scikit-learn</h1>
# <h4 class="sk-landing-subheader text-white font-italic mb-3">Machine Learning in Python</h4>
# <a class="btn sk-landing-btn mb-1" href="getting_started.html" role="button">Getting Started</a>
# <a class="btn sk-landing-btn mb-1" href="whats_new/v0.22.html" role="button">What's New in 0.22</a>
# <a class="btn sk-landing-btn mb-1" href="https://github.com/scikit-learn/scikit-learn" role="button">GitHub</a>
# </div>
# <div class="col-md-6 d-flex">
# <ul class="sk-landing-header-body">
# <li>Simple and efficient tools for predictive data analysis</li>
# <li>Accessible to everybody, and reusable in various contexts</li>
# <li>Built on NumPy, SciPy, and matplotlib</li>
# <li>Open source, commercially usable - BSD license</li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="container sk-landing-container pt-3 body" role="main">
# <div class="row no-gutters">
# <div class="col-md-4 mb-3 px-md-2 sk-px-xl-4">
# <div class="card h-100">
# <div class="card-body">
# <a href="supervised_learning.html#supervised-learning"><h4 class="sk-card-title card-title">Classification</h4></a>
# <p class="card-text">Identifying which category an object belongs to.</p>
# <p class="card-text"><strong>Applications:</strong> Spam detection, image recognition.</p></div></div></div></div></div></body></html>
# <strong>Algorithms:</strong>
# <a href="modules/svm.html#svm-classification">SVM</a>,
#           <a href="modules/neighbors.html#classification">nearest neighbors</a>,
#           <a href="modules/ensemble.html#forest">random forest</a>,
#           and <a href="supervised_learning.html#supervised-learning">more...</a>
#
# <div class="overflow-hidden mx-2 text-center flex-fill">
# <a aria-label="Classification" href="auto_examples/classification/plot_classifier_comparison.html">
# <img alt="Classifier comparison" class="sk-index-img" src="_images/sphx_glr_plot_classifier_comparison_001_carousel.png" style="width:initial;max-width:initial"/>
# </a>
# </div>
# <a class="sk-btn-primary btn text-white btn-block" href="auto_examples/index.html#classification" role="button">Examples</a>
#
#
# <div class="col-md-4 mb-3 px-md-2 sk-px-xl-4">
# <div class="card h-100">
# <div class="card-body">
# <a href="supervised_learning.html#supervised-learning"><h4 class="sk-card-title card-title">Regression</h4></a>
# <p class="card-text">Predicting a continuous-valued attribute associated with an object.</p>
# <p class="card-text"><strong>Applications:</strong> Drug response, Stock prices.</p></div></div></div>
# <strong>Algorithms:</strong>
# <a href="modules/svm.html#svm-regression">SVR</a>,
#           <a href="modules/linear_model.html#ridge-regression">nearest neighbors</a>,
#           <a href="modules/linear_model.html#lasso">random forest</a>,
#           and <a href="supervised_learning.html#supervised-learning">more...</a>
#
# <div class="overflow-hidden mx-2 text-center flex-fill">
# <a aria-label="Regression" href="auto_examples/ensemble/plot_adaboost_regression.html">
# <img alt="Decision Tree Regression with AdaBoost" class="sk-index-img" src="_images/sphx_glr_plot_adaboost_regression_thumb.png"/>
# </a>
# </div>
# <a class="sk-btn-primary btn text-white btn-block" href="auto_examples/index.html#examples" role="button">Examples</a>
#
#
# <div class="col-md-4 mb-3 px-md-2 sk-px-xl-4">
# <div class="card h-100">
# <div class="card-body">
# <a href="modules/clustering.html#clustering"><h4 class="sk-card-title card-title">Clustering</h4></a>
# <p class="card-text">Automatic grouping of similar objects into sets.</p>
# <p class="card-text"><strong>Applications:</strong> Customer segmentation, Grouping experiment outcomes</p></div></div></div>
# <strong>Algorithms:</strong>
# <a href="modules/clustering.html#k-means">k-Means</a>,
#           <a href="modules/clustering.html#spectral-clustering">spectral clustering</a>,
#           <a href="modules/clustering.html#mean-shift">mean-shift</a>,
#           and <a href="modules/clustering.html#clustering">more...</a>
#
# <div class="overflow-hidden mx-2 text-center flex-fill">
# <a aria-label="Clustering" href="auto_examples/cluster/plot_kmeans_digits.html">
# <img alt="A demo of K-Means clustering on the handwritten digits data" class="sk-index-img" src="_images/sphx_glr_plot_kmeans_digits_thumb.png"/>
# </a>
# </div>
# <a class="sk-btn-primary btn text-white btn-block" href="auto_examples/index.html#cluster-examples" role="button">Examples</a>
#
#
# <div class="col-md-4 mb-3 px-md-2 sk-px-xl-4">
# <div class="card h-100">
# <div class="card-body">
# <a href="modules/decomposition.html#decompositions"><h4 class="sk-card-title card-title">Dimensionality reduction</h4></a>
# <p class="card-text">Reducing the number of random variables to consider.</p>
# <p class="card-text"><strong>Applications:</strong> Visualization, Increased efficiency</p></div></div></div>
# <strong>Algorithms:</strong>
# <a href="modules/decomposition.html#pca">k-Means</a>,
#           <a href="modules/feature_selection.html#feature-selection">feature selection</a>,
#           <a href="modules/decomposition.html#nmf">non-negative matrix factorization</a>,
#           and <a href="modules/decomposition.html#decompositions">more...</a>
#
# <div class="overflow-hidden mx-2 text-center flex-fill">
# <a aria-label="Dimensionality reduction" href="auto_examples/decomposition/plot_pca_iris.html">
# <img alt="PCA example with Iris Data-set" class="sk-index-img" src="_images/sphx_glr_plot_pca_iris_thumb.png"/>
# </a>
# </div>
# <a class="sk-btn-primary btn text-white btn-block" href="auto_examples/index.html#decomposition-examples" role="button">Examples</a>
#
#
# <div class="col-md-4 mb-3 px-md-2 sk-px-xl-4">
# <div class="card h-100">
# <div class="card-body">
# <a href="model_selection.html#model-selection"><h4 class="sk-card-title card-title">Model selection</h4></a>
# <p class="card-text">Comparing, validating and choosing parameters and models.</p>
# <p class="card-text"><strong>Applications:</strong> Improved accuracy via parameter tuning</p></div></div></div>
# <strong>Algorithms:</strong>
# <a href="modules/grid_search.html#grid-search">grid search</a>,
#           <a href="modules/cross_validation.html#cross-validation">cross validation</a>,
#           <a href="modules/model_evaluation.html#model-evaluation">metrics</a>,
#           and <a href="modules/decomposition.html#decompositions">more...</a>
#
# <div class="overflow-hidden mx-2 text-center flex-fill">
# <a aria-label="Model selection" href="auto_examples/model_selection/plot_multi_metric_evaluation.html">
# <img alt="Demonstration of multi-metric evaluation on cross_val_score and GridSearchCV" class="sk-index-img" src="_images/sphx_glr_plot_multi_metric_evaluation_thumb.png"/>
# </a>
# </div>
# <a class="sk-btn-primary btn text-white btn-block" href="auto_examples/index.html#model-selection" role="button">Examples</a>
#
#
# <div class="col-md-4 mb-3 px-md-2 sk-px-xl-4">
# <div class="card h-100">
# <div class="card-body">
# <a href="modules/preprocessing.html#preprocessing"><h4 class="sk-card-title card-title">Preprocessing</h4></a>
# <p class="card-text">Feature extraction and normalization.</p>
# <p class="card-text"><strong>Applications:</strong>  Transforming input data such as text for use with machine learning algorithms.</p></div></div></div>
# <strong>Algorithms:</strong>
# <a href="modules/preprocessing.html#preprocessing">preprocessing</a>,
#           <a href="modules/feature_extraction.html#feature-extraction">feature extraction</a>,
#           and <a href="modules/preprocessing.html#preprocessing">more...</a>
#
# <div class="overflow-hidden mx-2 text-center flex-fill">
# <a aria-label="Preprocessing" href="auto_examples/preprocessing/plot_discretization_strategies.html">
# <img alt="Demonstrating the different strategies of KBinsDiscretizer" class="sk-index-img" src="_images/sphx_glr_plot_discretization_strategies_thumb.png"/>
# </a>
# </div>
# <a class="sk-btn-primary btn text-white btn-block" href="auto_examples/index.html#preprocessing" role="button">Examples</a>
#
#
#
#
# <div class="container-fluid sk-landing-bg-more-info py-3">
# <div class="container sk-landing-container">
# <div class="row">
# <div class="col-md-4">
# <h4 class="sk-landing-call-header">News</h4>
# <ul class="sk-landing-call-list list-unstyled">
# <li><strong>On-going development:</strong>
# <a href="https://scikit-learn.org/dev/whats_new.html"><strong>What's new</strong> (Changelog)</a>
# </li>
# <li><strong>December 2019.</strong> scikit-learn 0.22 is available for download (<a href="whats_new/v0.22.html#version-0-22-0">Changelog</a>).
#         </li>
# <li><strong>Scikit-learn from 0.21 requires Python 3.5 or greater.</strong>
# </li>
# <li><strong>July 2019.</strong> scikit-learn 0.21.3 (<a href="whats_new/v0.21.html#version-0-21-3">Changelog</a>) and 0.20.4 (<a href="whats_new/v0.20.html#version-0-20-4">Changelog</a>) are available for download.
#         </li>
# <li><strong>May 2019.</strong> scikit-learn 0.21.0 to 0.21.2 are available for download (<a href="whats_new/v0.21.html#version-0-21-2">Changelog</a>).
#         </li>
# <li><strong>March 2019.</strong> scikit-learn 0.20.3 is available for download (<a href="whats_new/v0.20.html#version-0-20-3">Changelog</a>).
#         </li>
# <li><strong>September 2018.</strong> scikit-learn 0.20.0 is available for download (<a href="whats_new/v0.20.html#version-0-20-0">Changelog</a>).
#         </li>
# <li><strong>July 2018.</strong> scikit-learn 0.19.2 is available for download (<a href="whats_new/v0.19.html#version-0-19-2">Changelog</a>).
#         </li>
# <li><strong>July 2017.</strong> scikit-learn 0.19.0 is available for download (<a href="whats_new/v0.19.html#version-0-19">Changelog</a>).
#         </li>
# </ul>
# </div>
# <div class="col-md-4">
# <h4 class="sk-landing-call-header">Community</h4>
# <ul class="sk-landing-call-list list-unstyled">
# <li><strong>About us:</strong> See <a href="about.html#people">authors</a> and <a href="developers/contributing.html">contributing</a></li>
# <li><strong>More Machine Learning:</strong> Find <a href="related_projects.html">related projects</a></li>
# <li><strong>Questions?</strong> See <a href="faq.html">FAQ</a> and <a href="https://stackoverflow.com/questions/tagged/scikit-learn">stackoverflow</a></li>
# <li><strong>Mailing list:</strong> <a href="https://mail.python.org/mailman/listinfo/scikit-learn">scikit-learn@python.org</a></li>
# <li><strong>Gitter:</strong> <a href="https://gitter.im/scikit-learn/scikit-learn">gitter.im/scikit-learn</a></li>
# </ul>
# <form action="https://www.paypal.com/cgi-bin/webscr" id="paypal-form" method="post" target="_top">
# <input name="cmd" type="hidden" value="_s-xclick"/>
# <input name="hosted_button_id" type="hidden" value="74EYUMF3FTSW8"/>
# </form>
# <a class="btn btn-warning btn-big sk-donate-btn mb-1" onclick="document.getElementById('paypal-form').submit(); ">Help us, <strong>donate!</strong></a>
# <a class="btn btn-warning btn-big mb-1" href="about.html#citing-scikit-learn"><strong>Cite us!</strong></a>
# </div>
# <div class="col-md-4">
# <h4 class="sk-landing-call-header">Who uses scikit-learn?</h4>
# <div class="carousel slide" data-ride="carousel" id="carouselExampleSlidesOnly">
# <div class="carousel-inner">
# <div class="carousel-item active">
# <img alt="inria" class="d-block mx-auto sk-who-uses-carousel-img img-thumbnail" src="_images/inria.png"/>
# <em>"We use scikit-learn to support leading-edge basic research [...]"</em>
# </div>
# <div class="carousel-item">
# <img alt="spotify" class="d-block mx-auto sk-who-uses-carousel-img img-thumbnail" src="_images/spotify.png"/>
# <em>"I think it's the most well-designed ML package I've seen so far."</em>
# </div>
# <div class="carousel-item">
# <img alt="change-logo" class="d-block mx-auto sk-who-uses-carousel-img img-thumbnail" src="_images/change-logo.png"/>
# <em>"scikit-learn's ease-of-use, performance and overall variety of algorithms implemented has proved invaluable [...]."</em>
# </div>
# <div class="carousel-item">
# <img alt="telecomparistech" class="d-block mx-auto sk-who-uses-carousel-img img-thumbnail" src="_images/telecomparistech.jpg"/>
# <em>"The great benefit of scikit-learn is its fast learning curve [...]"</em>
# </div>
# <div class="carousel-item">
# <img alt="aweber" class="d-block mx-auto sk-who-uses-carousel-img img-thumbnail" src="_images/aweber.png"/>
# <em>"It allows us to do AWesome stuff we would not otherwise accomplish"</em>
# </div>
# <div class="carousel-item">
# <img alt="yhat" class="d-block mx-auto sk-who-uses-carousel-img img-thumbnail" src="_images/yhat.png"/>
# <em>"scikit-learn makes doing advanced analysis in Python accessible to anyone."</em>
# </div>
# </div>
# </div>
# <p class="text-right">
# <a href="testimonials/testimonials.html">More testimonials</a>
# </p>
# </div>
# </div>
# </div>
# </div>
# <div class="container-fluid py-3">
# <div class="container sk-landing-container">
# <a class="sk-footer-funding-link" href="about.html#funding">
# <div class="text-center">
# <p class="mt-2">
#                   scikit-learn development and maintenance are financially supported by
#                 </p>
# <img class="sk-footer-funding-logo" src="_static/inria-small.png" title="INRIA"/>
# <img class="sk-footer-funding-logo" src="_static/columbia-small.png" title="Columbia University"/>
# <img class="sk-footer-funding-logo" src="_static/sloan_logo-small.png" title="Alfred P. Sloan Foundation"/>
# <img class="sk-footer-funding-logo" src="_static/sydney-stacked-small.png" title="The University of Sydney"/>
# <img class="sk-footer-funding-logo" src="_static/microsoft-small.png" title="Microsoft"/>
# <img class="sk-footer-funding-logo" src="_static/bcg-small.png" title="Boston Consulting Group"/>
# <img class="sk-footer-funding-logo" src="_static/axa-small.png" title="AXA Assurances"/>
# <img class="sk-footer-funding-logo" src="_static/bnp-small.png" title="BNP Paris Bas Cardif"/>
# <img class="sk-footer-funding-logo" src="_static/fujitsu-small.png" title="Fujitsu"/>
# <img class="sk-footer-funding-logo" src="_static/intel-small.png" title="Intel"/>
# <img class="sk-footer-funding-logo" src="_static/nvidia-small.png" title="Nvidia"/>
# <img class="sk-footer-funding-logo" src="_static/dataiku-small.png" title="Dataiku"/>
# <img class="sk-footer-funding-logo" src="_static/anaconda-small.png" title="Anaconda"/>
# </div>
# </a>
# </div>
# </div>
# <script src="_static/js/vendor/bootstrap.min.js"></script>
# <script>
#     window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;
#     ga('create', 'UA-22606712-2', 'auto');
#     ga('set', 'anonymizeIp', true);
#     ga('send', 'pageview');
# </script>
# <script async="" src="https://www.google-analytics.com/analytics.js"></script>
# <script>
# $(document).ready(function() {
#     /* Add a [>>>] button on the top-right corner of code samples to hide
#      * the >>> and ... prompts and the output and thus make the code
#      * copyable. */
#     var div = $('.highlight-python .highlight,' +
#                 '.highlight-python3 .highlight,' +
#                 '.highlight-pycon .highlight,' +
# 		'.highlight-default .highlight')
#     var pre = div.find('pre');
#
#     // get the styles from the current theme
#     pre.parent().parent().css('position', 'relative');
#     var hide_text = 'Hide prompts and outputs';
#     var show_text = 'Show prompts and outputs';
#
#     // create and add the button to all the code blocks that contain >>>
#     div.each(function(index) {
#         var jthis = $(this);
#         if (jthis.find('.gp').length > 0) {
#             var button = $('<span class="copybutton">&gt;&gt;&gt;</span>');
#             button.attr('title', hide_text);
#             button.data('hidden', 'false');
#             jthis.prepend(button);
#         }
#         // tracebacks (.gt) contain bare text elements that need to be
#         // wrapped in a span to work with .nextUntil() (see later)
#         jthis.find('pre:has(.gt)').contents().filter(function() {
#             return ((this.nodeType == 3) && (this.data.trim().length > 0));
#         }).wrap('<span>');
#     });
#
#     // define the behavior of the button when it's clicked
#     $('.copybutton').click(function(e){
#         e.preventDefault();
#         var button = $(this);
#         if (button.data('hidden') === 'false') {
#             // hide the code output
#             button.parent().find('.go, .gp, .gt').hide();
#             button.next('pre').find('.gt').nextUntil('.gp, .go').css('visibility', 'hidden');
#             button.css('text-decoration', 'line-through');
#             button.attr('title', show_text);
#             button.data('hidden', 'true');
#         } else {
#             // show the code output
#             button.parent().find('.go, .gp, .gt').show();
#             button.next('pre').find('.gt').nextUntil('.gp, .go').css('visibility', 'visible');
#             button.css('text-decoration', 'none');
#             button.attr('title', hide_text);
#             button.data('hidden', 'false');
#         }
#     });
#
# 	/*** Add permalink buttons next to glossary terms ***/
# 	$('dl.glossary > dt[id]').append(function() {
# 		return ('<a class="headerlink" href="#' +
# 			    this.getAttribute('id') +
# 			    '" title="Permalink to this term">¶</a>');
# 	});
# });
#
# </script>
# <script src="https://scikit-learn.org/versionwarning.js"></script>

# %%
soup.prettify
# Out:
# <bound method Tag.prettify of
# <!DOCTYPE html>
#
# <!--[if IE 8]><html class="no-js lt-ie9" lang="en" > <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en"> <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="scikit-learn: machine learning in Python" name="Description"/>
# <title>scikit-learn: machine learning in Python — scikit-learn 0.22 documentation</title>
# <link href="http://scikit-learn.org/stable/index.html" rel="canonical"/>
# <link href="_static/favicon.ico" rel="shortcut icon"/>
# <link href="_static/css/vendor/bootstrap.min.css" rel="stylesheet" type="text/css"/>
# <link href="_static/gallery.css" rel="stylesheet" type="text/css"/>
# <link href="_static/css/theme.css" rel="stylesheet" type="text/css"/>
# <script data-url_root="./" id="documentation_options" src="_static/documentation_options.js"></script>
# <script src="_static/jquery.js"></script>
# </head>
# <body>
# <nav class="sk-landing-navbar navbar navbar-expand-md navbar-light bg-light py-0" id="navbar">
# <div class="container-fluid sk-landing-container px-0">
# <a class="navbar-brand py-0" href="#">
# <img alt="logo" class="sk-brand-img" src="_static/scikit-learn-logo-small.png"/>
# </a>
# <button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#navbarSupportedContent" data-toggle="collapse" id="sk-navbar-toggler" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <div class="sk-navbar-collapse collapse navbar-collapse" id="navbarSupportedContent">
# <ul class="navbar-nav mr-auto">
# <li class="nav-item">
# <a class="sk-nav-link nav-link" href="install.html">Install</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link" href="modules/classes.html">API</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link" href="auto_examples/index.html">Examples</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="getting_started.html">Getting Started</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="tutorial/index.html">Tutorial</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="glossary.html">Glossary</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="developers/index.html">Development</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="faq.html">FAQ</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="related_projects.html">Related packages</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="roadmap.html">Roadmap</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="about.html">About us</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>
# </li>
# <li class="nav-item dropdown nav-more-item-dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="sk-nav-link nav-link dropdown-toggle" data-toggle="dropdown" href="#" id="navbarDropdown" role="button">More</a>
# <div aria-labelledby="navbarDropdown" class="dropdown-menu">
# <a class="sk-nav-dropdown-item dropdown-item" href="getting_started.html">Getting Started</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="tutorial/index.html">Tutorial</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="glossary.html">Glossary</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="developers/index.html">Development</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="faq.html">FAQ</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="related_projects.html">Related packages</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="roadmap.html">Roadmap</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="about.html">About us</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>
# </div>
# </li>
# </ul>
# <div id="searchbox" role="search">
# <div class="searchformwrapper">
# <form action="search.html" class="search" method="get">
# <input aria-labelledby="searchlabel" class="sk-search-text-input" name="q" type="text"/>
# <input class="sk-search-text-btn" type="submit" value="Go"/>
# </form>
# </div>
# </div>
# </div>
# </div>
# </nav>
# <div class="container-fluid sk-landing-bg py-3">
# <div class="container sk-landing-container">
# <div class="row">
# <div class="col-md-6 mb-3 mb-md-0">
# <h1 class="sk-landing-header text-white text-monospace">scikit-learn</h1>
# <h4 class="sk-landing-subheader text-white font-italic mb-3">Machine Learning in Python</h4>
# <a class="btn sk-landing-btn mb-1" href="getting_started.html" role="button">Getting Started</a>
# <a class="btn sk-landing-btn mb-1" href="whats_new/v0.22.html" role="button">What's New in 0.22</a>
# <a class="btn sk-landing-btn mb-1" href="https://github.com/scikit-learn/scikit-learn" role="button">GitHub</a>
# </div>
# <div class="col-md-6 d-flex">
# <ul class="sk-landing-header-body">
# <li>Simple and efficient tools for predictive data analysis</li>
# <li>Accessible to everybody, and reusable in various contexts</li>
# <li>Built on NumPy, SciPy, and matplotlib</li>
# <li>Open source, commercially usable - BSD license</li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="container sk-landing-container pt-3 body" role="main">
# <div class="row no-gutters">
# <div class="col-md-4 mb-3 px-md-2 sk-px-xl-4">
# <div class="card h-100">
# <div class="card-body">
# <a href="supervised_learning.html#supervised-learning"><h4 class="sk-card-title card-title">Classification</h4></a>
# <p class="card-text">Identifying which category an object belongs to.</p>
# <p class="card-text"><strong>Applications:</strong> Spam detection, image recognition.</p></div></div></div></div></div></body></html>
# <strong>Algorithms:</strong>
# <a href="modules/svm.html#svm-classification">SVM</a>,
#           <a href="modules/neighbors.html#classification">nearest neighbors</a>,
#           <a href="modules/ensemble.html#forest">random forest</a>,
#           and <a href="supervised_learning.html#supervised-learning">more...</a>
#
# <div class="overflow-hidden mx-2 text-center flex-fill">
# <a aria-label="Classification" href="auto_examples/classification/plot_classifier_comparison.html">
# <img alt="Classifier comparison" class="sk-index-img" src="_images/sphx_glr_plot_classifier_comparison_001_carousel.png" style="width:initial;max-width:initial"/>
# </a>
# </div>
# <a class="sk-btn-primary btn text-white btn-block" href="auto_examples/index.html#classification" role="button">Examples</a>
#
#
# <div class="col-md-4 mb-3 px-md-2 sk-px-xl-4">
# <div class="card h-100">
# <div class="card-body">
# <a href="supervised_learning.html#supervised-learning"><h4 class="sk-card-title card-title">Regression</h4></a>
# <p class="card-text">Predicting a continuous-valued attribute associated with an object.</p>
# <p class="card-text"><strong>Applications:</strong> Drug response, Stock prices.</p></div></div></div>
# <strong>Algorithms:</strong>
# <a href="modules/svm.html#svm-regression">SVR</a>,
#           <a href="modules/linear_model.html#ridge-regression">nearest neighbors</a>,
#           <a href="modules/linear_model.html#lasso">random forest</a>,
#           and <a href="supervised_learning.html#supervised-learning">more...</a>
#
# <div class="overflow-hidden mx-2 text-center flex-fill">
# <a aria-label="Regression" href="auto_examples/ensemble/plot_adaboost_regression.html">
# <img alt="Decision Tree Regression with AdaBoost" class="sk-index-img" src="_images/sphx_glr_plot_adaboost_regression_thumb.png"/>
# </a>
# </div>
# <a class="sk-btn-primary btn text-white btn-block" href="auto_examples/index.html#examples" role="button">Examples</a>
#
#
# <div class="col-md-4 mb-3 px-md-2 sk-px-xl-4">
# <div class="card h-100">
# <div class="card-body">
# <a href="modules/clustering.html#clustering"><h4 class="sk-card-title card-title">Clustering</h4></a>
# <p class="card-text">Automatic grouping of similar objects into sets.</p>
# <p class="card-text"><strong>Applications:</strong> Customer segmentation, Grouping experiment outcomes</p></div></div></div>
# <strong>Algorithms:</strong>
# <a href="modules/clustering.html#k-means">k-Means</a>,
#           <a href="modules/clustering.html#spectral-clustering">spectral clustering</a>,
#           <a href="modules/clustering.html#mean-shift">mean-shift</a>,
#           and <a href="modules/clustering.html#clustering">more...</a>
#
# <div class="overflow-hidden mx-2 text-center flex-fill">
# <a aria-label="Clustering" href="auto_examples/cluster/plot_kmeans_digits.html">
# <img alt="A demo of K-Means clustering on the handwritten digits data" class="sk-index-img" src="_images/sphx_glr_plot_kmeans_digits_thumb.png"/>
# </a>
# </div>
# <a class="sk-btn-primary btn text-white btn-block" href="auto_examples/index.html#cluster-examples" role="button">Examples</a>
#
#
# <div class="col-md-4 mb-3 px-md-2 sk-px-xl-4">
# <div class="card h-100">
# <div class="card-body">
# <a href="modules/decomposition.html#decompositions"><h4 class="sk-card-title card-title">Dimensionality reduction</h4></a>
# <p class="card-text">Reducing the number of random variables to consider.</p>
# <p class="card-text"><strong>Applications:</strong> Visualization, Increased efficiency</p></div></div></div>
# <strong>Algorithms:</strong>
# <a href="modules/decomposition.html#pca">k-Means</a>,
#           <a href="modules/feature_selection.html#feature-selection">feature selection</a>,
#           <a href="modules/decomposition.html#nmf">non-negative matrix factorization</a>,
#           and <a href="modules/decomposition.html#decompositions">more...</a>
#
# <div class="overflow-hidden mx-2 text-center flex-fill">
# <a aria-label="Dimensionality reduction" href="auto_examples/decomposition/plot_pca_iris.html">
# <img alt="PCA example with Iris Data-set" class="sk-index-img" src="_images/sphx_glr_plot_pca_iris_thumb.png"/>
# </a>
# </div>
# <a class="sk-btn-primary btn text-white btn-block" href="auto_examples/index.html#decomposition-examples" role="button">Examples</a>
#
#
# <div class="col-md-4 mb-3 px-md-2 sk-px-xl-4">
# <div class="card h-100">
# <div class="card-body">
# <a href="model_selection.html#model-selection"><h4 class="sk-card-title card-title">Model selection</h4></a>
# <p class="card-text">Comparing, validating and choosing parameters and models.</p>
# <p class="card-text"><strong>Applications:</strong> Improved accuracy via parameter tuning</p></div></div></div>
# <strong>Algorithms:</strong>
# <a href="modules/grid_search.html#grid-search">grid search</a>,
#           <a href="modules/cross_validation.html#cross-validation">cross validation</a>,
#           <a href="modules/model_evaluation.html#model-evaluation">metrics</a>,
#           and <a href="modules/decomposition.html#decompositions">more...</a>
#
# <div class="overflow-hidden mx-2 text-center flex-fill">
# <a aria-label="Model selection" href="auto_examples/model_selection/plot_multi_metric_evaluation.html">
# <img alt="Demonstration of multi-metric evaluation on cross_val_score and GridSearchCV" class="sk-index-img" src="_images/sphx_glr_plot_multi_metric_evaluation_thumb.png"/>
# </a>
# </div>
# <a class="sk-btn-primary btn text-white btn-block" href="auto_examples/index.html#model-selection" role="button">Examples</a>
#
#
# <div class="col-md-4 mb-3 px-md-2 sk-px-xl-4">
# <div class="card h-100">
# <div class="card-body">
# <a href="modules/preprocessing.html#preprocessing"><h4 class="sk-card-title card-title">Preprocessing</h4></a>
# <p class="card-text">Feature extraction and normalization.</p>
# <p class="card-text"><strong>Applications:</strong>  Transforming input data such as text for use with machine learning algorithms.</p></div></div></div>
# <strong>Algorithms:</strong>
# <a href="modules/preprocessing.html#preprocessing">preprocessing</a>,
#           <a href="modules/feature_extraction.html#feature-extraction">feature extraction</a>,
#           and <a href="modules/preprocessing.html#preprocessing">more...</a>
#
# <div class="overflow-hidden mx-2 text-center flex-fill">
# <a aria-label="Preprocessing" href="auto_examples/preprocessing/plot_discretization_strategies.html">
# <img alt="Demonstrating the different strategies of KBinsDiscretizer" class="sk-index-img" src="_images/sphx_glr_plot_discretization_strategies_thumb.png"/>
# </a>
# </div>
# <a class="sk-btn-primary btn text-white btn-block" href="auto_examples/index.html#preprocessing" role="button">Examples</a>
#
#
#
#
# <div class="container-fluid sk-landing-bg-more-info py-3">
# <div class="container sk-landing-container">
# <div class="row">
# <div class="col-md-4">
# <h4 class="sk-landing-call-header">News</h4>
# <ul class="sk-landing-call-list list-unstyled">
# <li><strong>On-going development:</strong>
# <a href="https://scikit-learn.org/dev/whats_new.html"><strong>What's new</strong> (Changelog)</a>
# </li>
# <li><strong>December 2019.</strong> scikit-learn 0.22 is available for download (<a href="whats_new/v0.22.html#version-0-22-0">Changelog</a>).
#         </li>
# <li><strong>Scikit-learn from 0.21 requires Python 3.5 or greater.</strong>
# </li>
# <li><strong>July 2019.</strong> scikit-learn 0.21.3 (<a href="whats_new/v0.21.html#version-0-21-3">Changelog</a>) and 0.20.4 (<a href="whats_new/v0.20.html#version-0-20-4">Changelog</a>) are available for download.
#         </li>
# <li><strong>May 2019.</strong> scikit-learn 0.21.0 to 0.21.2 are available for download (<a href="whats_new/v0.21.html#version-0-21-2">Changelog</a>).
#         </li>
# <li><strong>March 2019.</strong> scikit-learn 0.20.3 is available for download (<a href="whats_new/v0.20.html#version-0-20-3">Changelog</a>).
#         </li>
# <li><strong>September 2018.</strong> scikit-learn 0.20.0 is available for download (<a href="whats_new/v0.20.html#version-0-20-0">Changelog</a>).
#         </li>
# <li><strong>July 2018.</strong> scikit-learn 0.19.2 is available for download (<a href="whats_new/v0.19.html#version-0-19-2">Changelog</a>).
#         </li>
# <li><strong>July 2017.</strong> scikit-learn 0.19.0 is available for download (<a href="whats_new/v0.19.html#version-0-19">Changelog</a>).
#         </li>
# </ul>
# </div>
# <div class="col-md-4">
# <h4 class="sk-landing-call-header">Community</h4>
# <ul class="sk-landing-call-list list-unstyled">
# <li><strong>About us:</strong> See <a href="about.html#people">authors</a> and <a href="developers/contributing.html">contributing</a></li>
# <li><strong>More Machine Learning:</strong> Find <a href="related_projects.html">related projects</a></li>
# <li><strong>Questions?</strong> See <a href="faq.html">FAQ</a> and <a href="https://stackoverflow.com/questions/tagged/scikit-learn">stackoverflow</a></li>
# <li><strong>Mailing list:</strong> <a href="https://mail.python.org/mailman/listinfo/scikit-learn">scikit-learn@python.org</a></li>
# <li><strong>Gitter:</strong> <a href="https://gitter.im/scikit-learn/scikit-learn">gitter.im/scikit-learn</a></li>
# </ul>
# <form action="https://www.paypal.com/cgi-bin/webscr" id="paypal-form" method="post" target="_top">
# <input name="cmd" type="hidden" value="_s-xclick"/>
# <input name="hosted_button_id" type="hidden" value="74EYUMF3FTSW8"/>
# </form>
# <a class="btn btn-warning btn-big sk-donate-btn mb-1" onclick="document.getElementById('paypal-form').submit(); ">Help us, <strong>donate!</strong></a>
# <a class="btn btn-warning btn-big mb-1" href="about.html#citing-scikit-learn"><strong>Cite us!</strong></a>
# </div>
# <div class="col-md-4">
# <h4 class="sk-landing-call-header">Who uses scikit-learn?</h4>
# <div class="carousel slide" data-ride="carousel" id="carouselExampleSlidesOnly">
# <div class="carousel-inner">
# <div class="carousel-item active">
# <img alt="inria" class="d-block mx-auto sk-who-uses-carousel-img img-thumbnail" src="_images/inria.png"/>
# <em>"We use scikit-learn to support leading-edge basic research [...]"</em>
# </div>
# <div class="carousel-item">
# <img alt="spotify" class="d-block mx-auto sk-who-uses-carousel-img img-thumbnail" src="_images/spotify.png"/>
# <em>"I think it's the most well-designed ML package I've seen so far."</em>
# </div>
# <div class="carousel-item">
# <img alt="change-logo" class="d-block mx-auto sk-who-uses-carousel-img img-thumbnail" src="_images/change-logo.png"/>
# <em>"scikit-learn's ease-of-use, performance and overall variety of algorithms implemented has proved invaluable [...]."</em>
# </div>
# <div class="carousel-item">
# <img alt="telecomparistech" class="d-block mx-auto sk-who-uses-carousel-img img-thumbnail" src="_images/telecomparistech.jpg"/>
# <em>"The great benefit of scikit-learn is its fast learning curve [...]"</em>
# </div>
# <div class="carousel-item">
# <img alt="aweber" class="d-block mx-auto sk-who-uses-carousel-img img-thumbnail" src="_images/aweber.png"/>
# <em>"It allows us to do AWesome stuff we would not otherwise accomplish"</em>
# </div>
# <div class="carousel-item">
# <img alt="yhat" class="d-block mx-auto sk-who-uses-carousel-img img-thumbnail" src="_images/yhat.png"/>
# <em>"scikit-learn makes doing advanced analysis in Python accessible to anyone."</em>
# </div>
# </div>
# </div>
# <p class="text-right">
# <a href="testimonials/testimonials.html">More testimonials</a>
# </p>
# </div>
# </div>
# </div>
# </div>
# <div class="container-fluid py-3">
# <div class="container sk-landing-container">
# <a class="sk-footer-funding-link" href="about.html#funding">
# <div class="text-center">
# <p class="mt-2">
#                   scikit-learn development and maintenance are financially supported by
#                 </p>
# <img class="sk-footer-funding-logo" src="_static/inria-small.png" title="INRIA"/>
# <img class="sk-footer-funding-logo" src="_static/columbia-small.png" title="Columbia University"/>
# <img class="sk-footer-funding-logo" src="_static/sloan_logo-small.png" title="Alfred P. Sloan Foundation"/>
# <img class="sk-footer-funding-logo" src="_static/sydney-stacked-small.png" title="The University of Sydney"/>
# <img class="sk-footer-funding-logo" src="_static/microsoft-small.png" title="Microsoft"/>
# <img class="sk-footer-funding-logo" src="_static/bcg-small.png" title="Boston Consulting Group"/>
# <img class="sk-footer-funding-logo" src="_static/axa-small.png" title="AXA Assurances"/>
# <img class="sk-footer-funding-logo" src="_static/bnp-small.png" title="BNP Paris Bas Cardif"/>
# <img class="sk-footer-funding-logo" src="_static/fujitsu-small.png" title="Fujitsu"/>
# <img class="sk-footer-funding-logo" src="_static/intel-small.png" title="Intel"/>
# <img class="sk-footer-funding-logo" src="_static/nvidia-small.png" title="Nvidia"/>
# <img class="sk-footer-funding-logo" src="_static/dataiku-small.png" title="Dataiku"/>
# <img class="sk-footer-funding-logo" src="_static/anaconda-small.png" title="Anaconda"/>
# </div>
# </a>
# </div>
# </div>
# <script src="_static/js/vendor/bootstrap.min.js"></script>
# <script>
#     window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;
#     ga('create', 'UA-22606712-2', 'auto');
#     ga('set', 'anonymizeIp', true);
#     ga('send', 'pageview');
# </script>
# <script async="" src="https://www.google-analytics.com/analytics.js"></script>
# <script>
# $(document).ready(function() {
#     /* Add a [>>>] button on the top-right corner of code samples to hide
#      * the >>> and ... prompts and the output and thus make the code
#      * copyable. */
#     var div = $('.highlight-python .highlight,' +
#                 '.highlight-python3 .highlight,' +
#                 '.highlight-pycon .highlight,' +
# 		'.highlight-default .highlight')
#     var pre = div.find('pre');
#
#     // get the styles from the current theme
#     pre.parent().parent().css('position', 'relative');
#     var hide_text = 'Hide prompts and outputs';
#     var show_text = 'Show prompts and outputs';
#
#     // create and add the button to all the code blocks that contain >>>
#     div.each(function(index) {
#         var jthis = $(this);
#         if (jthis.find('.gp').length > 0) {
#             var button = $('<span class="copybutton">&gt;&gt;&gt;</span>');
#             button.attr('title', hide_text);
#             button.data('hidden', 'false');
#             jthis.prepend(button);
#         }
#         // tracebacks (.gt) contain bare text elements that need to be
#         // wrapped in a span to work with .nextUntil() (see later)
#         jthis.find('pre:has(.gt)').contents().filter(function() {
#             return ((this.nodeType == 3) && (this.data.trim().length > 0));
#         }).wrap('<span>');
#     });
#
#     // define the behavior of the button when it's clicked
#     $('.copybutton').click(function(e){
#         e.preventDefault();
#         var button = $(this);
#         if (button.data('hidden') === 'false') {
#             // hide the code output
#             button.parent().find('.go, .gp, .gt').hide();
#             button.next('pre').find('.gt').nextUntil('.gp, .go').css('visibility', 'hidden');
#             button.css('text-decoration', 'line-through');
#             button.attr('title', show_text);
#             button.data('hidden', 'true');
#         } else {
#             // show the code output
#             button.parent().find('.go, .gp, .gt').show();
#             button.next('pre').find('.gt').nextUntil('.gp, .go').css('visibility', 'visible');
#             button.css('text-decoration', 'none');
#             button.attr('title', hide_text);
#             button.data('hidden', 'false');
#         }
#     });
#
# 	/*** Add permalink buttons next to glossary terms ***/
# 	$('dl.glossary > dt[id]').append(function() {
# 		return ('<a class="headerlink" href="#' +
# 			    this.getAttribute('id') +
# 			    '" title="Permalink to this term">¶</a>');
# 	});
# });
#
# </script>
# <script src="https://scikit-learn.org/versionwarning.js"></script>
#
# >

# %% [markdown]
# # step 3: HTML Tree traversal

# %% [markdown]
# ### Commonly used types of object..
# 1. Tag
# 2. NavigableString
# 3. BeautifulSoup
# 4. Comment

# %%
# 1. Tag
title = soup.title
type(title)
# Out:
# bs4.element.Tag

# %%
# 2. NavigableString
type(title.string)
# Out:
# bs4.element.NavigableString

# %%
# 3. BeautifulSoup
type(soup)
# Out:
# bs4.BeautifulSoup

# %% [markdown]
# ### Get the title of HTML page

# %%
title = soup.title
title
# Out:
# <title>scikit-learn: machine learning in Python — scikit-learn 0.22 documentation</title>

# %% [markdown]
# ### Get all the paragraphs from the page

# %%
paras = soup.find_all('p')
paras
# Out:
# [<p class="card-text">Identifying which category an object belongs to.</p>,
#  <p class="card-text"><strong>Applications:</strong> Spam detection, image recognition.</p>,
#  <p class="card-text">Predicting a continuous-valued attribute associated with an object.</p>,
#  <p class="card-text"><strong>Applications:</strong> Drug response, Stock prices.</p>,
#  <p class="card-text">Automatic grouping of similar objects into sets.</p>,
#  <p class="card-text"><strong>Applications:</strong> Customer segmentation, Grouping experiment outcomes</p>,
#  <p class="card-text">Reducing the number of random variables to consider.</p>,
#  <p class="card-text"><strong>Applications:</strong> Visualization, Increased efficiency</p>,
#  <p class="card-text">Comparing, validating and choosing parameters and models.</p>,
#  <p class="card-text"><strong>Applications:</strong> Improved accuracy via parameter tuning</p>,
#  <p class="card-text">Feature extraction and normalization.</p>,
#  <p class="card-text"><strong>Applications:</strong>  Transforming input data such as text for use with machine learning algorithms.</p>,
#  <p class="text-right">
#  <a href="testimonials/testimonials.html">More testimonials</a>
#  </p>,
#  <p class="mt-2">
#                    scikit-learn development and maintenance are financially supported by
#                  </p>]

# %% [markdown]
# ### Get all the anchor tags from the page

# %%
anchors = soup.find_all('a')
anchors
# Out:
# [<a class="navbar-brand py-0" href="#">
#  <img alt="logo" class="sk-brand-img" src="_static/scikit-learn-logo-small.png"/>
#  </a>,
#  <a class="sk-nav-link nav-link" href="install.html">Install</a>,
#  <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>,
#  <a class="sk-nav-link nav-link" href="modules/classes.html">API</a>,
#  <a class="sk-nav-link nav-link" href="auto_examples/index.html">Examples</a>,
#  <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="getting_started.html">Getting Started</a>,
#  <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="tutorial/index.html">Tutorial</a>,
#  <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="glossary.html">Glossary</a>,
#  <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="developers/index.html">Development</a>,
#  <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="faq.html">FAQ</a>,
#  <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="related_projects.html">Related packages</a>,
#  <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="roadmap.html">Roadmap</a>,
#  <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="about.html">About us</a>,
#  <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>,
#  <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>,
#  <a aria-expanded="false" aria-haspopup="true" class="sk-nav-link nav-link dropdown-toggle" data-toggle="dropdown" href="#" id="navbarDropdown" role="button">More</a>,
#  <a class="sk-nav-dropdown-item dropdown-item" href="getting_started.html">Getting Started</a>,
#  <a class="sk-nav-dropdown-item dropdown-item" href="tutorial/index.html">Tutorial</a>,
#  <a class="sk-nav-dropdown-item dropdown-item" href="glossary.html">Glossary</a>,
#  <a class="sk-nav-dropdown-item dropdown-item" href="developers/index.html">Development</a>,
#  <a class="sk-nav-dropdown-item dropdown-item" href="faq.html">FAQ</a>,
#  <a class="sk-nav-dropdown-item dropdown-item" href="related_projects.html">Related packages</a>,
#  <a class="sk-nav-dropdown-item dropdown-item" href="roadmap.html">Roadmap</a>,
#  <a class="sk-nav-dropdown-item dropdown-item" href="about.html">About us</a>,
#  <a class="sk-nav-dropdown-item dropdown-item" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>,
#  <a class="sk-nav-dropdown-item dropdown-item" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>,
#  <a class="btn sk-landing-btn mb-1" href="getting_started.html" role="button">Getting Started</a>,
#  <a class="btn sk-landing-btn mb-1" href="whats_new/v0.22.html" role="button">What's New in 0.22</a>,
#  <a class="btn sk-landing-btn mb-1" href="https://github.com/scikit-learn/scikit-learn" role="button">GitHub</a>,
#  <a href="supervised_learning.html#supervised-learning"><h4 class="sk-card-title card-title">Classification</h4></a>,
#  <a href="modules/svm.html#svm-classification">SVM</a>,
#  <a href="modules/neighbors.html#classification">nearest neighbors</a>,
#  <a href="modules/ensemble.html#forest">random forest</a>,
#  <a href="supervised_learning.html#supervised-learning">more...</a>,
#  <a aria-label="Classification" href="auto_examples/classification/plot_classifier_comparison.html">
#  <img alt="Classifier comparison" class="sk-index-img" src="_images/sphx_glr_plot_classifier_comparison_001_carousel.png" style="width:initial;max-width:initial"/>
#  </a>,
#  <a class="sk-btn-primary btn text-white btn-block" href="auto_examples/index.html#classification" role="button">Examples</a>,
#  <a href="supervised_learning.html#supervised-learning"><h4 class="sk-card-title card-title">Regression</h4></a>,
#  <a href="modules/svm.html#svm-regression">SVR</a>,
#  <a href="modules/linear_model.html#ridge-regression">nearest neighbors</a>,
#  <a href="modules/linear_model.html#lasso">random forest</a>,
#  <a href="supervised_learning.html#supervised-learning">more...</a>,
#  <a aria-label="Regression" href="auto_examples/ensemble/plot_adaboost_regression.html">
#  <img alt="Decision Tree Regression with AdaBoost" class="sk-index-img" src="_images/sphx_glr_plot_adaboost_regression_thumb.png"/>
#  </a>,
#  <a class="sk-btn-primary btn text-white btn-block" href="auto_examples/index.html#examples" role="button">Examples</a>,
#  <a href="modules/clustering.html#clustering"><h4 class="sk-card-title card-title">Clustering</h4></a>,
#  <a href="modules/clustering.html#k-means">k-Means</a>,
#  <a href="modules/clustering.html#spectral-clustering">spectral clustering</a>,
#  <a href="modules/clustering.html#mean-shift">mean-shift</a>,
#  <a href="modules/clustering.html#clustering">more...</a>,
#  <a aria-label="Clustering" href="auto_examples/cluster/plot_kmeans_digits.html">
#  <img alt="A demo of K-Means clustering on the handwritten digits data" class="sk-index-img" src="_images/sphx_glr_plot_kmeans_digits_thumb.png"/>
#  </a>,
#  <a class="sk-btn-primary btn text-white btn-block" href="auto_examples/index.html#cluster-examples" role="button">Examples</a>,
#  <a href="modules/decomposition.html#decompositions"><h4 class="sk-card-title card-title">Dimensionality reduction</h4></a>,
#  <a href="modules/decomposition.html#pca">k-Means</a>,
#  <a href="modules/feature_selection.html#feature-selection">feature selection</a>,
#  <a href="modules/decomposition.html#nmf">non-negative matrix factorization</a>,
#  <a href="modules/decomposition.html#decompositions">more...</a>,
#  <a aria-label="Dimensionality reduction" href="auto_examples/decomposition/plot_pca_iris.html">
#  <img alt="PCA example with Iris Data-set" class="sk-index-img" src="_images/sphx_glr_plot_pca_iris_thumb.png"/>
#  </a>,
#  <a class="sk-btn-primary btn text-white btn-block" href="auto_examples/index.html#decomposition-examples" role="button">Examples</a>,
#  <a href="model_selection.html#model-selection"><h4 class="sk-card-title card-title">Model selection</h4></a>,
#  <a href="modules/grid_search.html#grid-search">grid search</a>,
#  <a href="modules/cross_validation.html#cross-validation">cross validation</a>,
#  <a href="modules/model_evaluation.html#model-evaluation">metrics</a>,
#  <a href="modules/decomposition.html#decompositions">more...</a>,
#  <a aria-label="Model selection" href="auto_examples/model_selection/plot_multi_metric_evaluation.html">
#  <img alt="Demonstration of multi-metric evaluation on cross_val_score and GridSearchCV" class="sk-index-img" src="_images/sphx_glr_plot_multi_metric_evaluation_thumb.png"/>
#  </a>,
#  <a class="sk-btn-primary btn text-white btn-block" href="auto_examples/index.html#model-selection" role="button">Examples</a>,
#  <a href="modules/preprocessing.html#preprocessing"><h4 class="sk-card-title card-title">Preprocessing</h4></a>,
#  <a href="modules/preprocessing.html#preprocessing">preprocessing</a>,
#  <a href="modules/feature_extraction.html#feature-extraction">feature extraction</a>,
#  <a href="modules/preprocessing.html#preprocessing">more...</a>,
#  <a aria-label="Preprocessing" href="auto_examples/preprocessing/plot_discretization_strategies.html">
#  <img alt="Demonstrating the different strategies of KBinsDiscretizer" class="sk-index-img" src="_images/sphx_glr_plot_discretization_strategies_thumb.png"/>
#  </a>,
#  <a class="sk-btn-primary btn text-white btn-block" href="auto_examples/index.html#preprocessing" role="button">Examples</a>,
#  <a href="https://scikit-learn.org/dev/whats_new.html"><strong>What's new</strong> (Changelog)</a>,
#  <a href="whats_new/v0.22.html#version-0-22-0">Changelog</a>,
#  <a href="whats_new/v0.21.html#version-0-21-3">Changelog</a>,
#  <a href="whats_new/v0.20.html#version-0-20-4">Changelog</a>,
#  <a href="whats_new/v0.21.html#version-0-21-2">Changelog</a>,
#  <a href="whats_new/v0.20.html#version-0-20-3">Changelog</a>,
#  <a href="whats_new/v0.20.html#version-0-20-0">Changelog</a>,
#  <a href="whats_new/v0.19.html#version-0-19-2">Changelog</a>,
#  <a href="whats_new/v0.19.html#version-0-19">Changelog</a>,
#  <a href="about.html#people">authors</a>,
#  <a href="developers/contributing.html">contributing</a>,
#  <a href="related_projects.html">related projects</a>,
#  <a href="faq.html">FAQ</a>,
#  <a href="https://stackoverflow.com/questions/tagged/scikit-learn">stackoverflow</a>,
#  <a href="https://mail.python.org/mailman/listinfo/scikit-learn">scikit-learn@python.org</a>,
#  <a href="https://gitter.im/scikit-learn/scikit-learn">gitter.im/scikit-learn</a>,
#  <a class="btn btn-warning btn-big sk-donate-btn mb-1" onclick="document.getElementById('paypal-form').submit(); ">Help us, <strong>donate!</strong></a>,
#  <a class="btn btn-warning btn-big mb-1" href="about.html#citing-scikit-learn"><strong>Cite us!</strong></a>,
#  <a href="testimonials/testimonials.html">More testimonials</a>,
#  <a class="sk-footer-funding-link" href="about.html#funding">
#  <div class="text-center">
#  <p class="mt-2">
#                    scikit-learn development and maintenance are financially supported by
#                  </p>
#  <img class="sk-footer-funding-logo" src="_static/inria-small.png" title="INRIA"/>
#  <img class="sk-footer-funding-logo" src="_static/columbia-small.png" title="Columbia University"/>
#  <img class="sk-footer-funding-logo" src="_static/sloan_logo-small.png" title="Alfred P. Sloan Foundation"/>
#  <img class="sk-footer-funding-logo" src="_static/sydney-stacked-small.png" title="The University of Sydney"/>
#  <img class="sk-footer-funding-logo" src="_static/microsoft-small.png" title="Microsoft"/>
#  <img class="sk-footer-funding-logo" src="_static/bcg-small.png" title="Boston Consulting Group"/>
#  <img class="sk-footer-funding-logo" src="_static/axa-small.png" title="AXA Assurances"/>
#  <img class="sk-footer-funding-logo" src="_static/bnp-small.png" title="BNP Paris Bas Cardif"/>
#  <img class="sk-footer-funding-logo" src="_static/fujitsu-small.png" title="Fujitsu"/>
#  <img class="sk-footer-funding-logo" src="_static/intel-small.png" title="Intel"/>
#  <img class="sk-footer-funding-logo" src="_static/nvidia-small.png" title="Nvidia"/>
#  <img class="sk-footer-funding-logo" src="_static/dataiku-small.png" title="Dataiku"/>
#  <img class="sk-footer-funding-logo" src="_static/anaconda-small.png" title="Anaconda"/>
#  </div>
#  </a>]

# %% [markdown]
# ### Get first element in the  HTML page

# %%
soup.find('p')
# Out:
# <p class="card-text">Identifying which category an object belongs to.</p>

# %% [markdown]
# ### Get the classes of any elements int he HTML page

# %%
soup.find('p')['class']
# Out:
# ['card-text']

# %% [markdown]
# ### Find all the elements with the class lead

# %%
print(soup.find_all('p', class_ = "card-text"))
# Out:
# [<p class="card-text">Identifying which category an object belongs to.</p>, <p class="card-text"><strong>Applications:</strong> Spam detection, image recognition.</p>, <p class="card-text">Predicting a continuous-valued attribute associated with an object.</p>, <p class="card-text"><strong>Applications:</strong> Drug response, Stock prices.</p>, <p class="card-text">Automatic grouping of similar objects into sets.</p>, <p class="card-text"><strong>Applications:</strong> Customer segmentation, Grouping experiment outcomes</p>, <p class="card-text">Reducing the number of random variables to consider.</p>, <p class="card-text"><strong>Applications:</strong> Visualization, Increased efficiency</p>, <p class="card-text">Comparing, validating and choosing parameters and models.</p>, <p class="card-text"><strong>Applications:</strong> Improved accuracy via parameter tuning</p>, <p class="card-text">Feature extraction and normalization.</p>, <p class="card-text"><strong>Applications:</strong>  Transforming input data such as text for use with machine learning algorithms.</p>]

# %% [markdown]
# ### Get text from the tags/soup

# %%
print(soup.find('p').get_text())
# Out:
# Identifying which category an object belongs to.

# %%
print(soup.get_text())
# Out:
#
#
#
#
#
# scikit-learn: machine learning in Python — scikit-learn 0.22 documentation
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Install
#
#
# User Guide
#
#
# API
#
#
# Examples
#
#
# Getting Started
#
#
# Tutorial
#
#
# Glossary
#
#
# Development
#
#
# FAQ
#
#
# Related packages
#
#
# Roadmap
#
#
# About us
#
#
# GitHub
#
#
# Other Versions
#
#
# More
#
# Getting Started
# Tutorial
# Glossary
# Development
# FAQ
# Related packages
# Roadmap
# About us
# GitHub
# Other Versions
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# scikit-learn
# Machine Learning in Python
# Getting Started
# What's New in 0.22
# GitHub
#
#
#
# Simple and efficient tools for predictive data analysis
# Accessible to everybody, and reusable in various contexts
# Built on NumPy, SciPy, and matplotlib
# Open source, commercially usable - BSD license
#
#
#
#
#
#
#
#
#
#
# Classification
# Identifying which category an object belongs to.
# Applications: Spam detection, image recognition.
# Algorithms:
# SVM,
#           nearest neighbors,
#           random forest,
#           and more...
#
#
#
#
#
#
# Examples
#
#
#
#
#
# Regression
# Predicting a continuous-valued attribute associated with an object.
# Applications: Drug response, Stock prices.
# Algorithms:
# SVR,
#           nearest neighbors,
#           random forest,
#           and more...
#
#
#
#
#
#
# Examples
#
#
#
#
#
# Clustering
# Automatic grouping of similar objects into sets.
# Applications: Customer segmentation, Grouping experiment outcomes
# Algorithms:
# k-Means,
#           spectral clustering,
#           mean-shift,
#           and more...
#
#
#
#
#
#
# Examples
#
#
#
#
#
# Dimensionality reduction
# Reducing the number of random variables to consider.
# Applications: Visualization, Increased efficiency
# Algorithms:
# k-Means,
#           feature selection,
#           non-negative matrix factorization,
#           and more...
#
#
#
#
#
#
# Examples
#
#
#
#
#
# Model selection
# Comparing, validating and choosing parameters and models.
# Applications: Improved accuracy via parameter tuning
# Algorithms:
# grid search,
#           cross validation,
#           metrics,
#           and more...
#
#
#
#
#
#
# Examples
#
#
#
#
#
# Preprocessing
# Feature extraction and normalization.
# Applications:  Transforming input data such as text for use with machine learning algorithms.
# Algorithms:
# preprocessing,
#           feature extraction,
#           and more...
#
#
#
#
#
#
# Examples
#
#
#
#
#
#
#
#
# News
#
# On-going development:
# What's new (Changelog)
#
# December 2019. scikit-learn 0.22 is available for download (Changelog).
#
# Scikit-learn from 0.21 requires Python 3.5 or greater.
#
# July 2019. scikit-learn 0.21.3 (Changelog) and 0.20.4 (Changelog) are available for download.
#
# May 2019. scikit-learn 0.21.0 to 0.21.2 are available for download (Changelog).
#
# March 2019. scikit-learn 0.20.3 is available for download (Changelog).
#
# September 2018. scikit-learn 0.20.0 is available for download (Changelog).
#
# July 2018. scikit-learn 0.19.2 is available for download (Changelog).
#
# July 2017. scikit-learn 0.19.0 is available for download (Changelog).
#
#
#
#
# Community
#
# About us: See authors and contributing
# More Machine Learning: Find related projects
# Questions? See FAQ and stackoverflow
# Mailing list: scikit-learn@python.org
# Gitter: gitter.im/scikit-learn
#
#
#
#
#
# Help us, donate!
# Cite us!
#
#
# Who uses scikit-learn?
#
#
#
#
# "We use scikit-learn to support leading-edge basic research [...]"
#
#
#
# "I think it's the most well-designed ML package I've seen so far."
#
#
#
# "scikit-learn's ease-of-use, performance and overall variety of algorithms implemented has proved invaluable [...]."
#
#
#
# "The great benefit of scikit-learn is its fast learning curve [...]"
#
#
#
# "It allows us to do AWesome stuff we would not otherwise accomplish"
#
#
#
# "scikit-learn makes doing advanced analysis in Python accessible to anyone."
#
#
#
#
# More testimonials
#
#
#
#
#
#
#
#
#
#
#                   scikit-learn development and maintenance are financially supported by
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;
#     ga('create', 'UA-22606712-2', 'auto');
#     ga('set', 'anonymizeIp', true);
#     ga('send', 'pageview');
#
#
#
# $(document).ready(function() {
#     /* Add a [>>>] button on the top-right corner of code samples to hide
#      * the >>> and ... prompts and the output and thus make the code
#      * copyable. */
#     var div = $('.highlight-python .highlight,' +
#                 '.highlight-python3 .highlight,' +
#                 '.highlight-pycon .highlight,' +
# 		'.highlight-default .highlight')
#     var pre = div.find('pre');
#
#     // get the styles from the current theme
#     pre.parent().parent().css('position', 'relative');
#     var hide_text = 'Hide prompts and outputs';
#     var show_text = 'Show prompts and outputs';
#
#     // create and add the button to all the code blocks that contain >>>
#     div.each(function(index) {
#         var jthis = $(this);
#         if (jthis.find('.gp').length > 0) {
#             var button = $('<span class="copybutton">&gt;&gt;&gt;</span>');
#             button.attr('title', hide_text);
#             button.data('hidden', 'false');
#             jthis.prepend(button);
#         }
#         // tracebacks (.gt) contain bare text elements that need to be
#         // wrapped in a span to work with .nextUntil() (see later)
#         jthis.find('pre:has(.gt)').contents().filter(function() {
#             return ((this.nodeType == 3) && (this.data.trim().length > 0));
#         }).wrap('<span>');
#     });
#
#     // define the behavior of the button when it's clicked
#     $('.copybutton').click(function(e){
#         e.preventDefault();
#         var button = $(this);
#         if (button.data('hidden') === 'false') {
#             // hide the code output
#             button.parent().find('.go, .gp, .gt').hide();
#             button.next('pre').find('.gt').nextUntil('.gp, .go').css('visibility', 'hidden');
#             button.css('text-decoration', 'line-through');
#             button.attr('title', show_text);
#             button.data('hidden', 'true');
#         } else {
#             // show the code output
#             button.parent().find('.go, .gp, .gt').show();
#             button.next('pre').find('.gt').nextUntil('.gp, .go').css('visibility', 'visible');
#             button.css('text-decoration', 'none');
#             button.attr('title', hide_text);
#             button.data('hidden', 'false');
#         }
#     });
#
# 	/*** Add permalink buttons next to glossary terms ***/
# 	$('dl.glossary > dt[id]').append(function() {
# 		return ('<a class="headerlink" href="#' +
# 			    this.getAttribute('id') +
# 			    '" title="Permalink to this term">¶</a>');
# 	});
# });

# %% [markdown]
# ### Get all the links on the page

# %%
all_links = set()
for link in anchors:
    if(link.get('href') != '#'):
#         linkText = "https://scikit-learn.org/stable/" + link.get('href')
        all_links.add(link)
        print(all_links)
# Out:
# {<a class="sk-nav-link nav-link" href="install.html">Install</a>}
# {<a class="sk-nav-link nav-link" href="install.html">Install</a>, <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>}
# {<a class="sk-nav-link nav-link" href="install.html">Install</a>, <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>, <a class="sk-nav-link nav-link" href="modules/classes.html">API</a>}
# {<a class="sk-nav-link nav-link" href="install.html">Install</a>, <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>, <a class="sk-nav-link nav-link" href="auto_examples/index.html">Examples</a>, <a class="sk-nav-link nav-link" href="modules/classes.html">API</a>}
# {<a class="sk-nav-link nav-link nav-more-item-mobile-items" href="getting_started.html">Getting Started</a>, <a class="sk-nav-link nav-link" href="install.html">Install</a>, <a class="sk-nav-link nav-link" href="modules/classes.html">API</a>, <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>, <a class="sk-nav-link nav-link" href="auto_examples/index.html">Examples</a>}
# {<a class="sk-nav-link nav-link nav-more-item-mobile-items" href="getting_started.html">Getting Started</a>, <a class="sk-nav-link nav-link" href="install.html">Install</a>, <a class="sk-nav-link nav-link" href="modules/classes.html">API</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="tutorial/index.html">Tutorial</a>, <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>, <a class="sk-nav-link nav-link" href="auto_examples/index.html">Examples</a>}
# {<a class="sk-nav-link nav-link nav-more-item-mobile-items" href="getting_started.html">Getting Started</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="glossary.html">Glossary</a>, <a class="sk-nav-link nav-link" href="install.html">Install</a>, <a class="sk-nav-link nav-link" href="modules/classes.html">API</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="tutorial/index.html">Tutorial</a>, <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>, <a class="sk-nav-link nav-link" href="auto_examples/index.html">Examples</a>}
# {<a class="sk-nav-link nav-link nav-more-item-mobile-items" href="getting_started.html">Getting Started</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="glossary.html">Glossary</a>, <a class="sk-nav-link nav-link" href="install.html">Install</a>, <a class="sk-nav-link nav-link" href="modules/classes.html">API</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="tutorial/index.html">Tutorial</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="developers/index.html">Development</a>, <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>, <a class="sk-nav-link nav-link" href="auto_examples/index.html">Examples</a>}
# {<a class="sk-nav-link nav-link nav-more-item-mobile-items" href="faq.html">FAQ</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="getting_started.html">Getting Started</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="glossary.html">Glossary</a>, <a class="sk-nav-link nav-link" href="install.html">Install</a>, <a class="sk-nav-link nav-link" href="modules/classes.html">API</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="tutorial/index.html">Tutorial</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="developers/index.html">Development</a>, <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>, <a class="sk-nav-link nav-link" href="auto_examples/index.html">Examples</a>}
# {<a class="sk-nav-link nav-link nav-more-item-mobile-items" href="faq.html">FAQ</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="getting_started.html">Getting Started</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="glossary.html">Glossary</a>, <a class="sk-nav-link nav-link" href="install.html">Install</a>, <a class="sk-nav-link nav-link" href="modules/classes.html">API</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="tutorial/index.html">Tutorial</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="related_projects.html">Related packages</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="developers/index.html">Development</a>, <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>, <a class="sk-nav-link nav-link" href="auto_examples/index.html">Examples</a>}
# {<a class="sk-nav-link nav-link nav-more-item-mobile-items" href="faq.html">FAQ</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="getting_started.html">Getting Started</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="glossary.html">Glossary</a>, <a class="sk-nav-link nav-link" href="install.html">Install</a>, <a class="sk-nav-link nav-link" href="modules/classes.html">API</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="tutorial/index.html">Tutorial</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="related_projects.html">Related packages</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="developers/index.html">Development</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="roadmap.html">Roadmap</a>, <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>, <a class="sk-nav-link nav-link" href="auto_examples/index.html">Examples</a>}
# {<a class="sk-nav-link nav-link nav-more-item-mobile-items" href="faq.html">FAQ</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="getting_started.html">Getting Started</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="glossary.html">Glossary</a>, <a class="sk-nav-link nav-link" href="install.html">Install</a>, <a class="sk-nav-link nav-link" href="modules/classes.html">API</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="tutorial/index.html">Tutorial</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="related_projects.html">Related packages</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="about.html">About us</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="developers/index.html">Development</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="roadmap.html">Roadmap</a>, <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>, <a class="sk-nav-link nav-link" href="auto_examples/index.html">Examples</a>}
# {<a class="sk-nav-link nav-link nav-more-item-mobile-items" href="faq.html">FAQ</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="getting_started.html">Getting Started</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="glossary.html">Glossary</a>, <a class="sk-nav-link nav-link" href="install.html">Install</a>, <a class="sk-nav-link nav-link" href="modules/classes.html">API</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="tutorial/index.html">Tutorial</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="related_projects.html">Related packages</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="about.html">About us</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="developers/index.html">Development</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="roadmap.html">Roadmap</a>, <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>, <a class="sk-nav-link nav-link" href="auto_examples/index.html">Examples</a>}
# {<a class="sk-nav-link nav-link nav-more-item-mobile-items" href="faq.html">FAQ</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="getting_started.html">Getting Started</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="glossary.html">Glossary</a>, <a class="sk-nav-link nav-link" href="install.html">Install</a>, <a class="sk-nav-link nav-link" href="modules/classes.html">API</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="tutorial/index.html">Tutorial</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="related_projects.html">Related packages</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="about.html">About us</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="developers/index.html">Development</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="roadmap.html">Roadmap</a>, <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>, <a class="sk-nav-link nav-link" href="auto_examples/index.html">Examples</a>}
# {<a class="sk-nav-link nav-link nav-more-item-mobile-items" href="faq.html">FAQ</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="getting_started.html">Getting Started</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="glossary.html">Glossary</a>, <a class="sk-nav-link nav-link" href="install.html">Install</a>, <a class="sk-nav-link nav-link" href="modules/classes.html">API</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="tutorial/index.html">Tutorial</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>, <a class="sk-nav-dropdown-item dropdown-item" href="getting_started.html">Getting Started</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="related_projects.html">Related packages</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="about.html">About us</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="developers/index.html">Development</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="roadmap.html">Roadmap</a>, <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>, <a class="sk-nav-link nav-link" href="auto_examples/index.html">Examples</a>}
# {<a class="sk-nav-link nav-link nav-more-item-mobile-items" href="faq.html">FAQ</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="getting_started.html">Getting Started</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="glossary.html">Glossary</a>, <a class="sk-nav-link nav-link" href="install.html">Install</a>, <a class="sk-nav-link nav-link" href="modules/classes.html">API</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="tutorial/index.html">Tutorial</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>, <a class="sk-nav-dropdown-item dropdown-item" href="getting_started.html">Getting Started</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="related_projects.html">Related packages</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="about.html">About us</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="developers/index.html">Development</a>, <a class="sk-nav-dropdown-item dropdown-item" href="tutorial/index.html">Tutorial</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="roadmap.html">Roadmap</a>, <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>, <a class="sk-nav-link nav-link" href="auto_examples/index.html">Examples</a>}
# {<a class="sk-nav-link nav-link nav-more-item-mobile-items" href="faq.html">FAQ</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="getting_started.html">Getting Started</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="glossary.html">Glossary</a>, <a class="sk-nav-link nav-link" href="install.html">Install</a>, <a class="sk-nav-link nav-link" href="modules/classes.html">API</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="tutorial/index.html">Tutorial</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>, <a class="sk-nav-dropdown-item dropdown-item" href="getting_started.html">Getting Started</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="related_projects.html">Related packages</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="about.html">About us</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="developers/index.html">Development</a>, <a class="sk-nav-dropdown-item dropdown-item" href="tutorial/index.html">Tutorial</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="roadmap.html">Roadmap</a>, <a class="sk-nav-dropdown-item dropdown-item" href="glossary.html">Glossary</a>, <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>, <a class="sk-nav-link nav-link" href="auto_examples/index.html">Examples</a>}
# {<a class="sk-nav-link nav-link nav-more-item-mobile-items" href="faq.html">FAQ</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="getting_started.html">Getting Started</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="glossary.html">Glossary</a>, <a class="sk-nav-link nav-link" href="install.html">Install</a>, <a class="sk-nav-link nav-link" href="modules/classes.html">API</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="tutorial/index.html">Tutorial</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>, <a class="sk-nav-dropdown-item dropdown-item" href="getting_started.html">Getting Started</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="related_projects.html">Related packages</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="about.html">About us</a>, <a class="sk-nav-dropdown-item dropdown-item" href="developers/index.html">Development</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="developers/index.html">Development</a>, <a class="sk-nav-dropdown-item dropdown-item" href="tutorial/index.html">Tutorial</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="roadmap.html">Roadmap</a>, <a class="sk-nav-dropdown-item dropdown-item" href="glossary.html">Glossary</a>, <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>, <a class="sk-nav-link nav-link" href="auto_examples/index.html">Examples</a>}
# {<a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="tutorial/index.html">Tutorial</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="about.html">About us</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="developers/index.html">Development</a>, <a class="sk-nav-dropdown-item dropdown-item" href="glossary.html">Glossary</a>, <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="glossary.html">Glossary</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>, <a class="sk-nav-dropdown-item dropdown-item" href="developers/index.html">Development</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="roadmap.html">Roadmap</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="faq.html">FAQ</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="getting_started.html">Getting Started</a>, <a class="sk-nav-link nav-link" href="install.html">Install</a>, <a class="sk-nav-dropdown-item dropdown-item" href="tutorial/index.html">Tutorial</a>, <a class="sk-nav-link nav-link" href="modules/classes.html">API</a>, <a class="sk-nav-dropdown-item dropdown-item" href="getting_started.html">Getting Started</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="related_projects.html">Related packages</a>, <a class="sk-nav-dropdown-item dropdown-item" href="faq.html">FAQ</a>, <a class="sk-nav-link nav-link" href="auto_examples/index.html">Examples</a>}
# {<a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="tutorial/index.html">Tutorial</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="about.html">About us</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="developers/index.html">Development</a>, <a class="sk-nav-dropdown-item dropdown-item" href="glossary.html">Glossary</a>, <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="glossary.html">Glossary</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>, <a class="sk-nav-dropdown-item dropdown-item" href="developers/index.html">Development</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="roadmap.html">Roadmap</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="faq.html">FAQ</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="getting_started.html">Getting Started</a>, <a class="sk-nav-link nav-link" href="install.html">Install</a>, <a class="sk-nav-dropdown-item dropdown-item" href="tutorial/index.html">Tutorial</a>, <a class="sk-nav-link nav-link" href="modules/classes.html">API</a>, <a class="sk-nav-dropdown-item dropdown-item" href="getting_started.html">Getting Started</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="related_projects.html">Related packages</a>, <a class="sk-nav-dropdown-item dropdown-item" href="related_projects.html">Related packages</a>, <a class="sk-nav-dropdown-item dropdown-item" href="faq.html">FAQ</a>, <a class="sk-nav-link nav-link" href="auto_examples/index.html">Examples</a>}
# {<a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="tutorial/index.html">Tutorial</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="about.html">About us</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="developers/index.html">Development</a>, <a class="sk-nav-dropdown-item dropdown-item" href="glossary.html">Glossary</a>, <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="glossary.html">Glossary</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>, <a class="sk-nav-dropdown-item dropdown-item" href="developers/index.html">Development</a>, <a class="sk-nav-dropdown-item dropdown-item" href="roadmap.html">Roadmap</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="roadmap.html">Roadmap</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="faq.html">FAQ</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="getting_started.html">Getting Started</a>, <a class="sk-nav-link nav-link" href="install.html">Install</a>, <a class="sk-nav-dropdown-item dropdown-item" href="tutorial/index.html">Tutorial</a>, <a class="sk-nav-link nav-link" href="modules/classes.html">API</a>, <a class="sk-nav-dropdown-item dropdown-item" href="getting_started.html">Getting Started</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="related_projects.html">Related packages</a>, <a class="sk-nav-dropdown-item dropdown-item" href="related_projects.html">Related packages</a>, <a class="sk-nav-dropdown-item dropdown-item" href="faq.html">FAQ</a>, <a class="sk-nav-link nav-link" href="auto_examples/index.html">Examples</a>}
# {<a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="tutorial/index.html">Tutorial</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="about.html">About us</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="developers/index.html">Development</a>, <a class="sk-nav-dropdown-item dropdown-item" href="glossary.html">Glossary</a>, <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="glossary.html">Glossary</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>, <a class="sk-nav-dropdown-item dropdown-item" href="developers/index.html">Development</a>, <a class="sk-nav-dropdown-item dropdown-item" href="roadmap.html">Roadmap</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="roadmap.html">Roadmap</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="faq.html">FAQ</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="getting_started.html">Getting Started</a>, <a class="sk-nav-dropdown-item dropdown-item" href="about.html">About us</a>, <a class="sk-nav-link nav-link" href="install.html">Install</a>, <a class="sk-nav-dropdown-item dropdown-item" href="tutorial/index.html">Tutorial</a>, <a class="sk-nav-link nav-link" href="modules/classes.html">API</a>, <a class="sk-nav-dropdown-item dropdown-item" href="getting_started.html">Getting Started</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="related_projects.html">Related packages</a>, <a class="sk-nav-dropdown-item dropdown-item" href="related_projects.html">Related packages</a>, <a class="sk-nav-dropdown-item dropdown-item" href="faq.html">FAQ</a>, <a class="sk-nav-link nav-link" href="auto_examples/index.html">Examples</a>}
# {<a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="tutorial/index.html">Tutorial</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="about.html">About us</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="developers/index.html">Development</a>, <a class="sk-nav-dropdown-item dropdown-item" href="glossary.html">Glossary</a>, <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="glossary.html">Glossary</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>, <a class="sk-nav-dropdown-item dropdown-item" href="developers/index.html">Development</a>, <a class="sk-nav-dropdown-item dropdown-item" href="roadmap.html">Roadmap</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="roadmap.html">Roadmap</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="faq.html">FAQ</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="getting_started.html">Getting Started</a>, <a class="sk-nav-dropdown-item dropdown-item" href="about.html">About us</a>, <a class="sk-nav-link nav-link" href="install.html">Install</a>, <a class="sk-nav-dropdown-item dropdown-item" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>, <a class="sk-nav-dropdown-item dropdown-item" href="tutorial/index.html">Tutorial</a>, <a class="sk-nav-link nav-link" href="modules/classes.html">API</a>, <a class="sk-nav-dropdown-item dropdown-item" href="getting_started.html">Getting Started</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="related_projects.html">Related packages</a>, <a class="sk-nav-dropdown-item dropdown-item" href="related_projects.html">Related packages</a>, <a class="sk-nav-dropdown-item dropdown-item" href="faq.html">FAQ</a>, <a class="sk-nav-link nav-link" href="auto_examples/index.html">Examples</a>}
# {<a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="tutorial/index.html">Tutorial</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="about.html">About us</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="developers/index.html">Development</a>, <a class="sk-nav-dropdown-item dropdown-item" href="glossary.html">Glossary</a>, <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="glossary.html">Glossary</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>, <a class="sk-nav-dropdown-item dropdown-item" href="developers/index.html">Development</a>, <a class="sk-nav-dropdown-item dropdown-item" href="roadmap.html">Roadmap</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="roadmap.html">Roadmap</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="faq.html">FAQ</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="getting_started.html">Getting Started</a>, <a class="sk-nav-dropdown-item dropdown-item" href="about.html">About us</a>, <a class="sk-nav-link nav-link" href="install.html">Install</a>, <a class="sk-nav-dropdown-item dropdown-item" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>, <a class="sk-nav-dropdown-item dropdown-item" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>, <a class="sk-nav-dropdown-item dropdown-item" href="tutorial/index.html">Tutorial</a>, <a class="sk-nav-link nav-link" href="modules/classes.html">API</a>, <a class="sk-nav-dropdown-item dropdown-item" href="getting_started.html">Getting Started</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="related_projects.html">Related packages</a>, <a class="sk-nav-dropdown-item dropdown-item" href="related_projects.html">Related packages</a>, <a class="sk-nav-dropdown-item dropdown-item" href="faq.html">FAQ</a>, <a class="sk-nav-link nav-link" href="auto_examples/index.html">Examples</a>}
# {<a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="tutorial/index.html">Tutorial</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="about.html">About us</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="developers/index.html">Development</a>, <a class="sk-nav-dropdown-item dropdown-item" href="glossary.html">Glossary</a>, <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="glossary.html">Glossary</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>, <a class="sk-nav-dropdown-item dropdown-item" href="developers/index.html">Development</a>, <a class="sk-nav-dropdown-item dropdown-item" href="roadmap.html">Roadmap</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="roadmap.html">Roadmap</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="faq.html">FAQ</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="getting_started.html">Getting Started</a>, <a class="sk-nav-dropdown-item dropdown-item" href="about.html">About us</a>, <a class="sk-nav-link nav-link" href="install.html">Install</a>, <a class="sk-nav-dropdown-item dropdown-item" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>, <a class="sk-nav-dropdown-item dropdown-item" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>, <a class="sk-nav-dropdown-item dropdown-item" href="tutorial/index.html">Tutorial</a>, <a class="btn sk-landing-btn mb-1" href="getting_started.html" role="button">Getting Started</a>, <a class="sk-nav-link nav-link" href="modules/classes.html">API</a>, <a class="sk-nav-dropdown-item dropdown-item" href="getting_started.html">Getting Started</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="related_projects.html">Related packages</a>, <a class="sk-nav-dropdown-item dropdown-item" href="related_projects.html">Related packages</a>, <a class="sk-nav-dropdown-item dropdown-item" href="faq.html">FAQ</a>, <a class="sk-nav-link nav-link" href="auto_examples/index.html">Examples</a>}
# {<a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="tutorial/index.html">Tutorial</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="about.html">About us</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="developers/index.html">Development</a>, <a class="sk-nav-dropdown-item dropdown-item" href="glossary.html">Glossary</a>, <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="glossary.html">Glossary</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>, <a class="sk-nav-dropdown-item dropdown-item" href="developers/index.html">Development</a>, <a class="sk-nav-dropdown-item dropdown-item" href="roadmap.html">Roadmap</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="roadmap.html">Roadmap</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="faq.html">FAQ</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="getting_started.html">Getting Started</a>, <a class="sk-nav-dropdown-item dropdown-item" href="about.html">About us</a>, <a class="sk-nav-link nav-link" href="install.html">Install</a>, <a class="sk-nav-dropdown-item dropdown-item" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>, <a class="sk-nav-dropdown-item dropdown-item" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>, <a class="sk-nav-dropdown-item dropdown-item" href="tutorial/index.html">Tutorial</a>, <a class="btn sk-landing-btn mb-1" href="getting_started.html" role="button">Getting Started</a>, <a class="btn sk-landing-btn mb-1" href="whats_new/v0.22.html" role="button">What's New in 0.22</a>, <a class="sk-nav-link nav-link" href="modules/classes.html">API</a>, <a class="sk-nav-dropdown-item dropdown-item" href="getting_started.html">Getting Started</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="related_projects.html">Related packages</a>, <a class="sk-nav-dropdown-item dropdown-item" href="related_projects.html">Related packages</a>, <a class="sk-nav-dropdown-item dropdown-item" href="faq.html">FAQ</a>, <a class="sk-nav-link nav-link" href="auto_examples/index.html">Examples</a>}
# {<a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="tutorial/index.html">Tutorial</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="about.html">About us</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="developers/index.html">Development</a>, <a class="sk-nav-dropdown-item dropdown-item" href="glossary.html">Glossary</a>, <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="glossary.html">Glossary</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>, <a class="sk-nav-dropdown-item dropdown-item" href="developers/index.html">Development</a>, <a class="sk-nav-dropdown-item dropdown-item" href="roadmap.html">Roadmap</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="roadmap.html">Roadmap</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="faq.html">FAQ</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="getting_started.html">Getting Started</a>, <a class="sk-nav-dropdown-item dropdown-item" href="about.html">About us</a>, <a class="sk-nav-link nav-link" href="install.html">Install</a>, <a class="sk-nav-dropdown-item dropdown-item" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>, <a class="sk-nav-dropdown-item dropdown-item" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>, <a class="sk-nav-dropdown-item dropdown-item" href="tutorial/index.html">Tutorial</a>, <a class="btn sk-landing-btn mb-1" href="getting_started.html" role="button">Getting Started</a>, <a class="btn sk-landing-btn mb-1" href="whats_new/v0.22.html" role="button">What's New in 0.22</a>, <a class="sk-nav-link nav-link" href="modules/classes.html">API</a>, <a class="sk-nav-dropdown-item dropdown-item" href="getting_started.html">Getting Started</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="related_projects.html">Related packages</a>, <a class="sk-nav-dropdown-item dropdown-item" href="related_projects.html">Related packages</a>, <a class="btn sk-landing-btn mb-1" href="https://github.com/scikit-learn/scikit-learn" role="button">GitHub</a>, <a class="sk-nav-dropdown-item dropdown-item" href="faq.html">FAQ</a>, <a class="sk-nav-link nav-link" href="auto_examples/index.html">Examples</a>}
# {<a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="tutorial/index.html">Tutorial</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="about.html">About us</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="developers/index.html">Development</a>, <a class="sk-nav-dropdown-item dropdown-item" href="glossary.html">Glossary</a>, <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="glossary.html">Glossary</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>, <a href="supervised_learning.html#supervised-learning"><h4 class="sk-card-title card-title">Classification</h4></a>, <a class="sk-nav-dropdown-item dropdown-item" href="developers/index.html">Development</a>, <a class="sk-nav-dropdown-item dropdown-item" href="roadmap.html">Roadmap</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="roadmap.html">Roadmap</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="faq.html">FAQ</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="getting_started.html">Getting Started</a>, <a class="sk-nav-dropdown-item dropdown-item" href="about.html">About us</a>, <a class="sk-nav-link nav-link" href="install.html">Install</a>, <a class="sk-nav-dropdown-item dropdown-item" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>, <a class="sk-nav-dropdown-item dropdown-item" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>, <a class="sk-nav-dropdown-item dropdown-item" href="tutorial/index.html">Tutorial</a>, <a class="btn sk-landing-btn mb-1" href="getting_started.html" role="button">Getting Started</a>, <a class="btn sk-landing-btn mb-1" href="whats_new/v0.22.html" role="button">What's New in 0.22</a>, <a class="sk-nav-link nav-link" href="modules/classes.html">API</a>, <a class="sk-nav-dropdown-item dropdown-item" href="getting_started.html">Getting Started</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="related_projects.html">Related packages</a>, <a class="sk-nav-dropdown-item dropdown-item" href="related_projects.html">Related packages</a>, <a class="btn sk-landing-btn mb-1" href="https://github.com/scikit-learn/scikit-learn" role="button">GitHub</a>, <a class="sk-nav-dropdown-item dropdown-item" href="faq.html">FAQ</a>, <a class="sk-nav-link nav-link" href="auto_examples/index.html">Examples</a>}
# {<a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="tutorial/index.html">Tutorial</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="about.html">About us</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="developers/index.html">Development</a>, <a class="sk-nav-dropdown-item dropdown-item" href="glossary.html">Glossary</a>, <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="glossary.html">Glossary</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>, <a href="supervised_learning.html#supervised-learning"><h4 class="sk-card-title card-title">Classification</h4></a>, <a class="sk-nav-dropdown-item dropdown-item" href="developers/index.html">Development</a>, <a class="sk-nav-dropdown-item dropdown-item" href="roadmap.html">Roadmap</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="roadmap.html">Roadmap</a>, <a href="modules/svm.html#svm-classification">SVM</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="faq.html">FAQ</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="getting_started.html">Getting Started</a>, <a class="sk-nav-dropdown-item dropdown-item" href="about.html">About us</a>, <a class="sk-nav-link nav-link" href="install.html">Install</a>, <a class="sk-nav-dropdown-item dropdown-item" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>, <a class="sk-nav-dropdown-item dropdown-item" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>, <a class="sk-nav-dropdown-item dropdown-item" href="tutorial/index.html">Tutorial</a>, <a class="btn sk-landing-btn mb-1" href="getting_started.html" role="button">Getting Started</a>, <a class="btn sk-landing-btn mb-1" href="whats_new/v0.22.html" role="button">What's New in 0.22</a>, <a class="sk-nav-link nav-link" href="modules/classes.html">API</a>, <a class="sk-nav-dropdown-item dropdown-item" href="getting_started.html">Getting Started</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="related_projects.html">Related packages</a>, <a class="sk-nav-dropdown-item dropdown-item" href="related_projects.html">Related packages</a>, <a class="btn sk-landing-btn mb-1" href="https://github.com/scikit-learn/scikit-learn" role="button">GitHub</a>, <a class="sk-nav-dropdown-item dropdown-item" href="faq.html">FAQ</a>, <a class="sk-nav-link nav-link" href="auto_examples/index.html">Examples</a>}
# {<a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="tutorial/index.html">Tutorial</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="about.html">About us</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="developers/index.html">Development</a>, <a class="sk-nav-dropdown-item dropdown-item" href="glossary.html">Glossary</a>, <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="glossary.html">Glossary</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>, <a href="supervised_learning.html#supervised-learning"><h4 class="sk-card-title card-title">Classification</h4></a>, <a class="sk-nav-dropdown-item dropdown-item" href="developers/index.html">Development</a>, <a class="sk-nav-dropdown-item dropdown-item" href="roadmap.html">Roadmap</a>, <a href="modules/neighbors.html#classification">nearest neighbors</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="roadmap.html">Roadmap</a>, <a href="modules/svm.html#svm-classification">SVM</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="faq.html">FAQ</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="getting_started.html">Getting Started</a>, <a class="sk-nav-dropdown-item dropdown-item" href="about.html">About us</a>, <a class="sk-nav-link nav-link" href="install.html">Install</a>, <a class="sk-nav-dropdown-item dropdown-item" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>, <a class="sk-nav-dropdown-item dropdown-item" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>, <a class="sk-nav-dropdown-item dropdown-item" href="tutorial/index.html">Tutorial</a>, <a class="btn sk-landing-btn mb-1" href="getting_started.html" role="button">Getting Started</a>, <a class="btn sk-landing-btn mb-1" href="whats_new/v0.22.html" role="button">What's New in 0.22</a>, <a class="sk-nav-link nav-link" href="modules/classes.html">API</a>, <a class="sk-nav-dropdown-item dropdown-item" href="getting_started.html">Getting Started</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="related_projects.html">Related packages</a>, <a class="sk-nav-dropdown-item dropdown-item" href="related_projects.html">Related packages</a>, <a class="btn sk-landing-btn mb-1" href="https://github.com/scikit-learn/scikit-learn" role="button">GitHub</a>, <a class="sk-nav-dropdown-item dropdown-item" href="faq.html">FAQ</a>, <a class="sk-nav-link nav-link" href="auto_examples/index.html">Examples</a>}
# {<a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="tutorial/index.html">Tutorial</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="about.html">About us</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="developers/index.html">Development</a>, <a class="sk-nav-dropdown-item dropdown-item" href="glossary.html">Glossary</a>, <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="glossary.html">Glossary</a>, <a href="modules/ensemble.html#forest">random forest</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>, <a href="supervised_learning.html#supervised-learning"><h4 class="sk-card-title card-title">Classification</h4></a>, <a class="sk-nav-dropdown-item dropdown-item" href="developers/index.html">Development</a>, <a class="sk-nav-dropdown-item dropdown-item" href="roadmap.html">Roadmap</a>, <a href="modules/neighbors.html#classification">nearest neighbors</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="roadmap.html">Roadmap</a>, <a href="modules/svm.html#svm-classification">SVM</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="faq.html">FAQ</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="getting_started.html">Getting Started</a>, <a class="sk-nav-dropdown-item dropdown-item" href="about.html">About us</a>, <a class="sk-nav-link nav-link" href="install.html">Install</a>, <a class="sk-nav-dropdown-item dropdown-item" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>, <a class="sk-nav-dropdown-item dropdown-item" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>, <a class="sk-nav-dropdown-item dropdown-item" href="tutorial/index.html">Tutorial</a>, <a class="btn sk-landing-btn mb-1" href="getting_started.html" role="button">Getting Started</a>, <a class="btn sk-landing-btn mb-1" href="whats_new/v0.22.html" role="button">What's New in 0.22</a>, <a class="sk-nav-link nav-link" href="modules/classes.html">API</a>, <a class="sk-nav-dropdown-item dropdown-item" href="getting_started.html">Getting Started</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="related_projects.html">Related packages</a>, <a class="sk-nav-dropdown-item dropdown-item" href="related_projects.html">Related packages</a>, <a class="btn sk-landing-btn mb-1" href="https://github.com/scikit-learn/scikit-learn" role="button">GitHub</a>, <a class="sk-nav-dropdown-item dropdown-item" href="faq.html">FAQ</a>, <a class="sk-nav-link nav-link" href="auto_examples/index.html">Examples</a>}
# ...
# <img alt="Classifier comparison" class="sk-index-img" src="_images/sphx_glr_plot_classifier_comparison_001_carousel.png" style="width:initial;max-width:initial"/>
# </a>, <a class="btn btn-warning btn-big mb-1" href="about.html#citing-scikit-learn"><strong>Cite us!</strong></a>, <a href="developers/contributing.html">contributing</a>, <a href="model_selection.html#model-selection"><h4 class="sk-card-title card-title">Model selection</h4></a>, <a href="https://scikit-learn.org/dev/whats_new.html"><strong>What's new</strong> (Changelog)</a>, <a href="modules/ensemble.html#forest">random forest</a>, <a href="modules/svm.html#svm-regression">SVR</a>, <a href="modules/neighbors.html#classification">nearest neighbors</a>, <a href="modules/grid_search.html#grid-search">grid search</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="roadmap.html">Roadmap</a>, <a href="modules/svm.html#svm-classification">SVM</a>, <a href="whats_new/v0.20.html#version-0-20-0">Changelog</a>, <a href="modules/clustering.html#mean-shift">mean-shift</a>, <a href="whats_new/v0.20.html#version-0-20-3">Changelog</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="faq.html">FAQ</a>, <a class="sk-nav-dropdown-item dropdown-item" href="about.html">About us</a>, <a href="modules/feature_extraction.html#feature-extraction">feature extraction</a>, <a href="whats_new/v0.19.html#version-0-19-2">Changelog</a>, <a href="whats_new/v0.21.html#version-0-21-2">Changelog</a>, <a href="https://gitter.im/scikit-learn/scikit-learn">gitter.im/scikit-learn</a>, <a class="sk-nav-link nav-link" href="modules/classes.html">API</a>, <a class="sk-nav-dropdown-item dropdown-item" href="getting_started.html">Getting Started</a>, <a class="sk-btn-primary btn text-white btn-block" href="auto_examples/index.html#decomposition-examples" role="button">Examples</a>, <a aria-label="Model selection" href="auto_examples/model_selection/plot_multi_metric_evaluation.html">
# <img alt="Demonstration of multi-metric evaluation on cross_val_score and GridSearchCV" class="sk-index-img" src="_images/sphx_glr_plot_multi_metric_evaluation_thumb.png"/>
# </a>, <a class="btn sk-landing-btn mb-1" href="https://github.com/scikit-learn/scikit-learn" role="button">GitHub</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>, <a href="modules/preprocessing.html#preprocessing">more...</a>, <a href="modules/linear_model.html#lasso">random forest</a>, <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>, <a href="supervised_learning.html#supervised-learning"><h4 class="sk-card-title card-title">Regression</h4></a>, <a href="whats_new/v0.21.html#version-0-21-3">Changelog</a>, <a href="modules/cross_validation.html#cross-validation">cross validation</a>, <a class="sk-nav-dropdown-item dropdown-item" href="developers/index.html">Development</a>, <a class="sk-btn-primary btn text-white btn-block" href="auto_examples/index.html#model-selection" role="button">Examples</a>, <a class="sk-btn-primary btn text-white btn-block" href="auto_examples/index.html#examples" role="button">Examples</a>, <a class="sk-nav-dropdown-item dropdown-item" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>, <a class="btn sk-landing-btn mb-1" href="getting_started.html" role="button">Getting Started</a>, <a href="whats_new/v0.22.html#version-0-22-0">Changelog</a>, <a href="whats_new/v0.19.html#version-0-19">Changelog</a>, <a class="btn sk-landing-btn mb-1" href="whats_new/v0.22.html" role="button">What's New in 0.22</a>, <a href="modules/clustering.html#spectral-clustering">spectral clustering</a>, <a href="modules/model_evaluation.html#model-evaluation">metrics</a>, <a href="whats_new/v0.20.html#version-0-20-4">Changelog</a>, <a href="modules/preprocessing.html#preprocessing"><h4 class="sk-card-title card-title">Preprocessing</h4></a>, <a class="sk-btn-primary btn text-white btn-block" href="auto_examples/index.html#cluster-examples" role="button">Examples</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="about.html">About us</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>, <a href="supervised_learning.html#supervised-learning"><h4 class="sk-card-title card-title">Classification</h4></a>, <a href="supervised_learning.html#supervised-learning">more...</a>, <a class="sk-nav-dropdown-item dropdown-item" href="roadmap.html">Roadmap</a>, <a href="faq.html">FAQ</a>, <a aria-label="Preprocessing" href="auto_examples/preprocessing/plot_discretization_strategies.html">
# <img alt="Demonstrating the different strategies of KBinsDiscretizer" class="sk-index-img" src="_images/sphx_glr_plot_discretization_strategies_thumb.png"/>
# </a>, <a href="modules/preprocessing.html#preprocessing">preprocessing</a>, <a class="sk-nav-link nav-link" href="install.html">Install</a>, <a class="sk-nav-dropdown-item dropdown-item" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>, <a class="sk-nav-dropdown-item dropdown-item" href="tutorial/index.html">Tutorial</a>, <a href="related_projects.html">related projects</a>, <a class="btn btn-warning btn-big sk-donate-btn mb-1" onclick="document.getElementById('paypal-form').submit(); ">Help us, <strong>donate!</strong></a>, <a class="sk-btn-primary btn text-white btn-block" href="auto_examples/index.html#classification" role="button">Examples</a>, <a class="sk-btn-primary btn text-white btn-block" href="auto_examples/index.html#preprocessing" role="button">Examples</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="related_projects.html">Related packages</a>, <a class="sk-nav-dropdown-item dropdown-item" href="faq.html">FAQ</a>, <a href="modules/decomposition.html#decompositions"><h4 class="sk-card-title card-title">Dimensionality reduction</h4></a>, <a href="https://stackoverflow.com/questions/tagged/scikit-learn">stackoverflow</a>, <a class="sk-nav-link nav-link" href="auto_examples/index.html">Examples</a>, <a href="https://mail.python.org/mailman/listinfo/scikit-learn">scikit-learn@python.org</a>, <a href="modules/clustering.html#k-means">k-Means</a>}
# {<a class="sk-footer-funding-link" href="about.html#funding">
# <div class="text-center">
# <p class="mt-2">
#                   scikit-learn development and maintenance are financially supported by
#                 </p>
# <img class="sk-footer-funding-logo" src="_static/inria-small.png" title="INRIA"/>
# <img class="sk-footer-funding-logo" src="_static/columbia-small.png" title="Columbia University"/>
# <img class="sk-footer-funding-logo" src="_static/sloan_logo-small.png" title="Alfred P. Sloan Foundation"/>
# <img class="sk-footer-funding-logo" src="_static/sydney-stacked-small.png" title="The University of Sydney"/>
# <img class="sk-footer-funding-logo" src="_static/microsoft-small.png" title="Microsoft"/>
# <img class="sk-footer-funding-logo" src="_static/bcg-small.png" title="Boston Consulting Group"/>
# <img class="sk-footer-funding-logo" src="_static/axa-small.png" title="AXA Assurances"/>
# <img class="sk-footer-funding-logo" src="_static/bnp-small.png" title="BNP Paris Bas Cardif"/>
# <img class="sk-footer-funding-logo" src="_static/fujitsu-small.png" title="Fujitsu"/>
# <img class="sk-footer-funding-logo" src="_static/intel-small.png" title="Intel"/>
# <img class="sk-footer-funding-logo" src="_static/nvidia-small.png" title="Nvidia"/>
# <img class="sk-footer-funding-logo" src="_static/dataiku-small.png" title="Dataiku"/>
# <img class="sk-footer-funding-logo" src="_static/anaconda-small.png" title="Anaconda"/>
# </div>
# </a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="tutorial/index.html">Tutorial</a>, <a href="modules/clustering.html#clustering"><h4 class="sk-card-title card-title">Clustering</h4></a>, <a aria-label="Clustering" href="auto_examples/cluster/plot_kmeans_digits.html">
# <img alt="A demo of K-Means clustering on the handwritten digits data" class="sk-index-img" src="_images/sphx_glr_plot_kmeans_digits_thumb.png"/>
# </a>, <a href="modules/decomposition.html#decompositions">more...</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="developers/index.html">Development</a>, <a class="sk-nav-dropdown-item dropdown-item" href="glossary.html">Glossary</a>, <a href="modules/linear_model.html#ridge-regression">nearest neighbors</a>, <a href="testimonials/testimonials.html">More testimonials</a>, <a href="modules/decomposition.html#pca">k-Means</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="glossary.html">Glossary</a>, <a href="modules/decomposition.html#nmf">non-negative matrix factorization</a>, <a href="modules/feature_selection.html#feature-selection">feature selection</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="getting_started.html">Getting Started</a>, <a href="about.html#people">authors</a>, <a aria-label="Regression" href="auto_examples/ensemble/plot_adaboost_regression.html">
# <img alt="Decision Tree Regression with AdaBoost" class="sk-index-img" src="_images/sphx_glr_plot_adaboost_regression_thumb.png"/>
# </a>, <a href="modules/clustering.html#clustering">more...</a>, <a aria-label="Dimensionality reduction" href="auto_examples/decomposition/plot_pca_iris.html">
# <img alt="PCA example with Iris Data-set" class="sk-index-img" src="_images/sphx_glr_plot_pca_iris_thumb.png"/>
# </a>, <a class="sk-nav-dropdown-item dropdown-item" href="related_projects.html">Related packages</a>, <a aria-label="Classification" href="auto_examples/classification/plot_classifier_comparison.html">
# <img alt="Classifier comparison" class="sk-index-img" src="_images/sphx_glr_plot_classifier_comparison_001_carousel.png" style="width:initial;max-width:initial"/>
# </a>, <a class="btn btn-warning btn-big mb-1" href="about.html#citing-scikit-learn"><strong>Cite us!</strong></a>, <a href="developers/contributing.html">contributing</a>, <a href="model_selection.html#model-selection"><h4 class="sk-card-title card-title">Model selection</h4></a>, <a href="https://scikit-learn.org/dev/whats_new.html"><strong>What's new</strong> (Changelog)</a>, <a href="modules/ensemble.html#forest">random forest</a>, <a href="modules/svm.html#svm-regression">SVR</a>, <a href="modules/neighbors.html#classification">nearest neighbors</a>, <a href="modules/grid_search.html#grid-search">grid search</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="roadmap.html">Roadmap</a>, <a href="modules/svm.html#svm-classification">SVM</a>, <a href="whats_new/v0.20.html#version-0-20-0">Changelog</a>, <a href="modules/clustering.html#mean-shift">mean-shift</a>, <a href="whats_new/v0.20.html#version-0-20-3">Changelog</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="faq.html">FAQ</a>, <a class="sk-nav-dropdown-item dropdown-item" href="about.html">About us</a>, <a href="modules/feature_extraction.html#feature-extraction">feature extraction</a>, <a href="whats_new/v0.19.html#version-0-19-2">Changelog</a>, <a href="whats_new/v0.21.html#version-0-21-2">Changelog</a>, <a href="https://gitter.im/scikit-learn/scikit-learn">gitter.im/scikit-learn</a>, <a class="sk-nav-link nav-link" href="modules/classes.html">API</a>, <a class="sk-nav-dropdown-item dropdown-item" href="getting_started.html">Getting Started</a>, <a class="sk-btn-primary btn text-white btn-block" href="auto_examples/index.html#decomposition-examples" role="button">Examples</a>, <a aria-label="Model selection" href="auto_examples/model_selection/plot_multi_metric_evaluation.html">
# <img alt="Demonstration of multi-metric evaluation on cross_val_score and GridSearchCV" class="sk-index-img" src="_images/sphx_glr_plot_multi_metric_evaluation_thumb.png"/>
# </a>, <a class="btn sk-landing-btn mb-1" href="https://github.com/scikit-learn/scikit-learn" role="button">GitHub</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>, <a href="modules/preprocessing.html#preprocessing">more...</a>, <a href="modules/linear_model.html#lasso">random forest</a>, <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>, <a href="supervised_learning.html#supervised-learning"><h4 class="sk-card-title card-title">Regression</h4></a>, <a href="whats_new/v0.21.html#version-0-21-3">Changelog</a>, <a href="modules/cross_validation.html#cross-validation">cross validation</a>, <a class="sk-nav-dropdown-item dropdown-item" href="developers/index.html">Development</a>, <a class="sk-btn-primary btn text-white btn-block" href="auto_examples/index.html#model-selection" role="button">Examples</a>, <a class="sk-btn-primary btn text-white btn-block" href="auto_examples/index.html#examples" role="button">Examples</a>, <a class="sk-nav-dropdown-item dropdown-item" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>, <a class="btn sk-landing-btn mb-1" href="getting_started.html" role="button">Getting Started</a>, <a href="whats_new/v0.22.html#version-0-22-0">Changelog</a>, <a href="whats_new/v0.19.html#version-0-19">Changelog</a>, <a class="btn sk-landing-btn mb-1" href="whats_new/v0.22.html" role="button">What's New in 0.22</a>, <a href="modules/clustering.html#spectral-clustering">spectral clustering</a>, <a href="modules/model_evaluation.html#model-evaluation">metrics</a>, <a href="whats_new/v0.20.html#version-0-20-4">Changelog</a>, <a href="modules/preprocessing.html#preprocessing"><h4 class="sk-card-title card-title">Preprocessing</h4></a>, <a class="sk-btn-primary btn text-white btn-block" href="auto_examples/index.html#cluster-examples" role="button">Examples</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="about.html">About us</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>, <a href="supervised_learning.html#supervised-learning"><h4 class="sk-card-title card-title">Classification</h4></a>, <a href="supervised_learning.html#supervised-learning">more...</a>, <a class="sk-nav-dropdown-item dropdown-item" href="roadmap.html">Roadmap</a>, <a href="faq.html">FAQ</a>, <a aria-label="Preprocessing" href="auto_examples/preprocessing/plot_discretization_strategies.html">
# <img alt="Demonstrating the different strategies of KBinsDiscretizer" class="sk-index-img" src="_images/sphx_glr_plot_discretization_strategies_thumb.png"/>
# </a>, <a href="modules/preprocessing.html#preprocessing">preprocessing</a>, <a class="sk-nav-link nav-link" href="install.html">Install</a>, <a class="sk-nav-dropdown-item dropdown-item" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>, <a class="sk-nav-dropdown-item dropdown-item" href="tutorial/index.html">Tutorial</a>, <a href="related_projects.html">related projects</a>, <a class="btn btn-warning btn-big sk-donate-btn mb-1" onclick="document.getElementById('paypal-form').submit(); ">Help us, <strong>donate!</strong></a>, <a class="sk-btn-primary btn text-white btn-block" href="auto_examples/index.html#classification" role="button">Examples</a>, <a class="sk-btn-primary btn text-white btn-block" href="auto_examples/index.html#preprocessing" role="button">Examples</a>, <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="related_projects.html">Related packages</a>, <a class="sk-nav-dropdown-item dropdown-item" href="faq.html">FAQ</a>, <a href="modules/decomposition.html#decompositions"><h4 class="sk-card-title card-title">Dimensionality reduction</h4></a>, <a href="https://stackoverflow.com/questions/tagged/scikit-learn">stackoverflow</a>, <a class="sk-nav-link nav-link" href="auto_examples/index.html">Examples</a>, <a href="https://mail.python.org/mailman/listinfo/scikit-learn">scikit-learn@python.org</a>, <a href="modules/clustering.html#k-means">k-Means</a>}

# %% [markdown]
# ### 4. comment

# %%
markup = "<p><!-- this is a comment --></p>"
soup2 = BeautifulSoup(markup)
soup2
# Out:
# <html><body><p><!-- this is a comment --></p></body></html>

# %%
print(soup2.p)
# Out:
# <p><!-- this is a comment --></p>

# %%
print(soup2.p.string)
# Out:
#  this is a comment

# %%
print(type(soup2.p.string))
# Out:
# <class 'bs4.element.Comment'>

# %% [markdown]
# .contents -> A tag's children are available as a list<br>
# .children -> A tag's children are available as a genrator

# %%
navbarSupportedContent = soup.find(id = 'navbarSupportedContent')

navbarSupportedContent.children

# %%
print(navbarSupportedContent.contents)
# Out:
# ['\n', <ul class="navbar-nav mr-auto">
# <li class="nav-item">
# <a class="sk-nav-link nav-link" href="install.html">Install</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link" href="modules/classes.html">API</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link" href="auto_examples/index.html">Examples</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="getting_started.html">Getting Started</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="tutorial/index.html">Tutorial</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="glossary.html">Glossary</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="developers/index.html">Development</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="faq.html">FAQ</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="related_projects.html">Related packages</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="roadmap.html">Roadmap</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="about.html">About us</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>
# </li>
# <li class="nav-item dropdown nav-more-item-dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="sk-nav-link nav-link dropdown-toggle" data-toggle="dropdown" href="#" id="navbarDropdown" role="button">More</a>
# <div aria-labelledby="navbarDropdown" class="dropdown-menu">
# <a class="sk-nav-dropdown-item dropdown-item" href="getting_started.html">Getting Started</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="tutorial/index.html">Tutorial</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="glossary.html">Glossary</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="developers/index.html">Development</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="faq.html">FAQ</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="related_projects.html">Related packages</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="roadmap.html">Roadmap</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="about.html">About us</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>
# </div>
# </li>
# </ul>, '\n', <div id="searchbox" role="search">
# <div class="searchformwrapper">
# <form action="search.html" class="search" method="get">
# <input aria-labelledby="searchlabel" class="sk-search-text-input" name="q" type="text"/>
# <input class="sk-search-text-btn" type="submit" value="Go"/>
# </form>
# </div>
# </div>, '\n']

# %%
for elem in navbarSupportedContent.contents:
    print(elem)
# Out:
# <ul class="navbar-nav mr-auto">
# <li class="nav-item">
# <a class="sk-nav-link nav-link" href="install.html">Install</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link" href="modules/classes.html">API</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link" href="auto_examples/index.html">Examples</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="getting_started.html">Getting Started</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="tutorial/index.html">Tutorial</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="glossary.html">Glossary</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="developers/index.html">Development</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="faq.html">FAQ</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="related_projects.html">Related packages</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="roadmap.html">Roadmap</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="about.html">About us</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>
# </li>
# <li class="nav-item dropdown nav-more-item-dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="sk-nav-link nav-link dropdown-toggle" data-toggle="dropdown" href="#" id="navbarDropdown" role="button">More</a>
# <div aria-labelledby="navbarDropdown" class="dropdown-menu">
# <a class="sk-nav-dropdown-item dropdown-item" href="getting_started.html">Getting Started</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="tutorial/index.html">Tutorial</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="glossary.html">Glossary</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="developers/index.html">Development</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="faq.html">FAQ</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="related_projects.html">Related packages</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="roadmap.html">Roadmap</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="about.html">About us</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>
# </div>
# </li>
# </ul>
#
#
# <div id="searchbox" role="search">
# <div class="searchformwrapper">
# <form action="search.html" class="search" method="get">
# <input aria-labelledby="searchlabel" class="sk-search-text-input" name="q" type="text"/>
# <input class="sk-search-text-btn" type="submit" value="Go"/>
# </form>
# </div>
# </div>

# %%
for item in navbarSupportedContent.strings:
    print(item)
# Out:
# Install
#
#
#
#
#
#
# User Guide
#
#
#
#
#
#
# API
#
#
#
#
#
#
# Examples
#
#
#
#
#
#
# Getting Started
#
#
#
#
#
#
# Tutorial
#
#
#
#
#
#
# Glossary
#
#
#
#
#
#
# Development
#
#
#
#
#
#
# FAQ
#
#
#
#
#
#
# Related packages
#
#
#
#
#
#
# Roadmap
#
#
#
#
#
#
# About us
#
#
#
#
#
#
# GitHub
#
#
#
#
#
#
# Other Versions
#
#
#
#
#
#
# More
#
#
#
#
# Getting Started
#
#
# Tutorial
#
#
# Glossary
#
#
# Development
#
#
# FAQ
#
#
# Related packages
#
#
# Roadmap
#
#
# About us
#
#
# GitHub
#
#
# Other Versions

# %%
for item in navbarSupportedContent.stripped_strings:
    print(item)
# Out:
# Install
# User Guide
# API
# Examples
# Getting Started
# Tutorial
# Glossary
# Development
# FAQ
# Related packages
# Roadmap
# About us
# GitHub
# Other Versions
# More
# Getting Started
# Tutorial
# Glossary
# Development
# FAQ
# Related packages
# Roadmap
# About us
# GitHub
# Other Versions

# %%
print(navbarSupportedContent.parent)
# Out:
# <div class="container-fluid sk-landing-container px-0">
# <a class="navbar-brand py-0" href="#">
# <img alt="logo" class="sk-brand-img" src="_static/scikit-learn-logo-small.png"/>
# </a>
# <button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#navbarSupportedContent" data-toggle="collapse" id="sk-navbar-toggler" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <div class="sk-navbar-collapse collapse navbar-collapse" id="navbarSupportedContent">
# <ul class="navbar-nav mr-auto">
# <li class="nav-item">
# <a class="sk-nav-link nav-link" href="install.html">Install</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link" href="modules/classes.html">API</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link" href="auto_examples/index.html">Examples</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="getting_started.html">Getting Started</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="tutorial/index.html">Tutorial</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="glossary.html">Glossary</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="developers/index.html">Development</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="faq.html">FAQ</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="related_projects.html">Related packages</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="roadmap.html">Roadmap</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="about.html">About us</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>
# </li>
# <li class="nav-item dropdown nav-more-item-dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="sk-nav-link nav-link dropdown-toggle" data-toggle="dropdown" href="#" id="navbarDropdown" role="button">More</a>
# <div aria-labelledby="navbarDropdown" class="dropdown-menu">
# <a class="sk-nav-dropdown-item dropdown-item" href="getting_started.html">Getting Started</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="tutorial/index.html">Tutorial</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="glossary.html">Glossary</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="developers/index.html">Development</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="faq.html">FAQ</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="related_projects.html">Related packages</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="roadmap.html">Roadmap</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="about.html">About us</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>
# </div>
# </li>
# </ul>
# <div id="searchbox" role="search">
# <div class="searchformwrapper">
# <form action="search.html" class="search" method="get">
# <input aria-labelledby="searchlabel" class="sk-search-text-input" name="q" type="text"/>
# <input class="sk-search-text-btn" type="submit" value="Go"/>
# </form>
# </div>
# </div>
# </div>
# </div>

# %%
for par in navbarSupportedContent.parent:
    print(par)
# Out:
# <a class="navbar-brand py-0" href="#">
# <img alt="logo" class="sk-brand-img" src="_static/scikit-learn-logo-small.png"/>
# </a>
#
#
# <button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#navbarSupportedContent" data-toggle="collapse" id="sk-navbar-toggler" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
#
#
# <div class="sk-navbar-collapse collapse navbar-collapse" id="navbarSupportedContent">
# <ul class="navbar-nav mr-auto">
# <li class="nav-item">
# <a class="sk-nav-link nav-link" href="install.html">Install</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link" href="user_guide.html">User Guide</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link" href="modules/classes.html">API</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link" href="auto_examples/index.html">Examples</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="getting_started.html">Getting Started</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="tutorial/index.html">Tutorial</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="glossary.html">Glossary</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="developers/index.html">Development</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="faq.html">FAQ</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="related_projects.html">Related packages</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="roadmap.html">Roadmap</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="about.html">About us</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>
# </li>
# <li class="nav-item">
# <a class="sk-nav-link nav-link nav-more-item-mobile-items" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>
# </li>
# <li class="nav-item dropdown nav-more-item-dropdown">
# <a aria-expanded="false" aria-haspopup="true" class="sk-nav-link nav-link dropdown-toggle" data-toggle="dropdown" href="#" id="navbarDropdown" role="button">More</a>
# <div aria-labelledby="navbarDropdown" class="dropdown-menu">
# <a class="sk-nav-dropdown-item dropdown-item" href="getting_started.html">Getting Started</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="tutorial/index.html">Tutorial</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="glossary.html">Glossary</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="developers/index.html">Development</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="faq.html">FAQ</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="related_projects.html">Related packages</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="roadmap.html">Roadmap</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="about.html">About us</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="https://github.com/scikit-learn/scikit-learn">GitHub</a>
# <a class="sk-nav-dropdown-item dropdown-item" href="https://scikit-learn.org/dev/versions.html">Other Versions</a>
# </div>
# </li>
# </ul>
# <div id="searchbox" role="search">
# <div class="searchformwrapper">
# <form action="search.html" class="search" method="get">
# <input aria-labelledby="searchlabel" class="sk-search-text-input" name="q" type="text"/>
# <input class="sk-search-text-btn" type="submit" value="Go"/>
# </form>
# </div>
# </div>
# </div>

# %%
for par in navbarSupportedContent.parents:
    print(par.name)
# Out:
# div
# nav
# body
# html
# [document]

# %%
print(navbarSupportedContent.next_sibling.next_sibling)
# Out:
# None

# %%
print(navbarSupportedContent.previous_sibling.previous_sibling)
# Out:
# <button aria-controls="navbarSupportedContent" aria-expanded="false" aria-label="Toggle navigation" class="navbar-toggler" data-target="#navbarSupportedContent" data-toggle="collapse" id="sk-navbar-toggler" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>

# %%
elem = soup.select('.d-flex')
print(elem)
# Out:
# [<div class="col-md-6 d-flex">
# <ul class="sk-landing-header-body">
# <li>Simple and efficient tools for predictive data analysis</li>
# <li>Accessible to everybody, and reusable in various contexts</li>
# <li>Built on NumPy, SciPy, and matplotlib</li>
# <li>Open source, commercially usable - BSD license</li>
# </ul>
# </div>]

# %%
elem = soup.select('.col-md-6')
print(elem)
# Out:
# [<div class="col-md-6 mb-3 mb-md-0">
# <h1 class="sk-landing-header text-white text-monospace">scikit-learn</h1>
# <h4 class="sk-landing-subheader text-white font-italic mb-3">Machine Learning in Python</h4>
# <a class="btn sk-landing-btn mb-1" href="getting_started.html" role="button">Getting Started</a>
# <a class="btn sk-landing-btn mb-1" href="whats_new/v0.22.html" role="button">What's New in 0.22</a>
# <a class="btn sk-landing-btn mb-1" href="https://github.com/scikit-learn/scikit-learn" role="button">GitHub</a>
# </div>, <div class="col-md-6 d-flex">
# <ul class="sk-landing-header-body">
# <li>Simple and efficient tools for predictive data analysis</li>
# <li>Accessible to everybody, and reusable in various contexts</li>
# <li>Built on NumPy, SciPy, and matplotlib</li>
# <li>Open source, commercially usable - BSD license</li>
# </ul>
# </div>]
